# %% [markdown]
# <a href="https://colab.research.google.com/github/Mart1n2015/MartinCerioli/blob/main/TS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from typing_extensions import Required
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import pandas as pd
import requests

# %%
url_dataset = "https://raw.githubusercontent.com/Mart1n2015/MartinCerioli/2ecf72ab3b51ec7a33bdcdcad861580635352f5e/Datos%20hist%C3%B3ricos%20de%20Tenaris%20ADR%20(TS).csv"

# %%
df = pd.read_csv(url_dataset,sep = ";")

# %%
df
# Out:
#           Fecha PETROLEO     TS   DÓLAR      S&P
# 0     30/6/2025    65,16  37,45  96,493  6204,95
# 1     27/6/2025    65,52  36,91  97,031  6173,07
# 2     26/6/2025    65,24  36,49  96,762  6141,02
# 3     25/6/2025    64,92  35,51  97,273  6092,16
# 4     24/6/2025    64,37   35,7   97,45  6092,18
# ...         ...      ...    ...     ...      ...
# 1104   4/2/2021    56,07  16,41   91,52   3871,7
# 1105   3/2/2021    55,54  16,26  91,148   3830,2
# 1106   2/2/2021    54,62  16,05  91,189   3826,3
# 1107   1/2/2021    53,42  15,79  90,975   3773,9
# 1108  29/1/2021    52,08  15,46  90,569   3714,2
#
# [1109 rows x 5 columns]

# %%
df['PETROLEO'] = df['PETROLEO'].str.replace(',', '.').astype(float)
df['TS'] = df['TS'].str.replace(',', '.').astype(float)
df['DÓLAR'] = df['DÓLAR'].str.replace(',', '.').astype(float)
df['S&P'] = df['S&P'].str.replace(',', '.').astype(float)

# %%
x1 = df ['PETROLEO']
x2 = df ['DÓLAR']
x3 = df ['S&P']
y = df ['TS']

# %%
modelo = LinearRegression()
X = pd.concat([x1, x2, x3], axis=1)
modelo.fit(X, y)
# Out:
# LinearRegression()

# %%
print(f"Coeficiente (pendiente): {modelo.coef_[0]:.4f}")
print(f"Intercepto: {modelo.intercept_:.4f}")
print(f"R² (bondad del ajuste): {modelo.score(X, y):.4f}")
# Out:
# Coeficiente (pendiente): 0.0308
# Intercepto: -52.2464
# R² (bondad del ajuste): 0.6553

# %%
url = "https://data912.com/live/usa_stocks"
param = {"symbol": "TS"}
response = requests.get(url, params=param)
data = response.json()

# %%
response = requests.get(url, params=param)
if response.status_code == 200:
    data = response.json()
    print(data)
else:
    print(f"Error {response.status_code}: {response.text}")
# Out:
# [{'symbol': 'A', 'q_bid': 1.0, 'px_bid': 125.89, 'px_ask': 125.94, 'q_ask': 6.0, 'v': 17156.0, 'q_op': 367.0, 'c': 125.93, 'pct_change': -0.31}, {'symbol': 'AA', 'q_bid': 35.0, 'px_bid': 32.41, 'px_ask': 32.42, 'q_ask': 100.0, 'v': 11938.0, 'q_op': 711.0, 'c': 32.4, 'pct_change': -0.18}, {'symbol': 'AAAU', 'q_bid': 35685.0, 'px_bid': 37.0, 'px_ask': 37.01, 'q_ask': 29434.0, 'v': 16004.0, 'q_op': 71.0, 'c': 37.0, 'pct_change': 1.69}, {'symbol': 'AACG', 'q_bid': 8.0, 'px_bid': 2.33, 'px_ask': 2.45, 'q_ask': 100.0, 'v': 339.0, 'q_op': 6.0, 'c': 2.37, 'pct_change': -3.27}, {'symbol': 'AAL', 'q_bid': 938.0, 'px_bid': 12.29, 'px_ask': 12.3, 'q_ask': 1530.0, 'v': 19576.0, 'q_op': 429.0, 'c': 12.29, 'pct_change': -1.29}, {'symbol': 'AAMI', 'q_bid': 136.0, 'px_bid': 48.75, 'px_ask': 48.8, 'q_ask': 1.0, 'v': 7581.0, 'q_op': 99.0, 'c': 48.76, 'pct_change': -0.2}, {'symbol': 'AAOI', 'q_bid': 226.0, 'px_bid': 30.65, 'px_ask': 30.71, 'q_ask': 63.0, 'v': 15090.0, 'q_op': 567.0, 'c': 30.64, 'pct_change': 5.69}, {'symbol': 'AAON', 'q_bid': 1.0, 'px_bid': 93.0, 'px_ask': 93.1, 'q_ask': 110.0, 'v': 22844.0, 'q_op': 267.0, 'c': 92.99, 'pct_change': 1.56}, {'symbol': 'AAP', 'q_bid': 11.0, 'px_bid': 61.06, 'px_ask': 61.1, 'q_ask': 200.0, 'v': 63464.0, 'q_op': 450.0, 'c': 61.03, 'pct_change': 3.97}, {'symbol': 'AAPL', 'q_bid': 200.0, 'px_bid': 255.13, 'px_ask': 255.15, 'q_ask': 50.0, 'v': 9270.0, 'q_op': 18790.0, 'c': 255.11, 'pct_change': 3.91}, {'symbol': 'AAT', 'q_bid': 150.0, 'px_bid': 20.81, 'px_ask': 20.82, 'q_ask': 6.0, 'v': 3478.0, 'q_op': 42.0, 'c': 20.79, 'pct_change': 0.19}, {'symbol': 'ABBV', 'q_bid': 13.0, 'px_bid': 223.34, 'px_ask': 223.46, 'q_ask': 10.0, 'v': 25257.0, 'q_op': 1573.0, 'c': 223.44, 'pct_change': 0.44}, {'symbol': 'ABCB', 'q_bid': 1.0, 'px_bid': 75.12, 'px_ask': 75.19, 'q_ask': 6.0, 'v': 7240.0, 'q_op': 164.0, 'c': 75.11, 'pct_change': -1.05}, {'symbol': 'ABCL', 'q_bid': 120.0, 'px_bid': 4.89, 'px_ask': 4.9, 'q_ask': 135.0, 'v': 60943.0, 'q_op': 194.0, 'c': 4.895, 'pct_change': 8.54}, {'symbol': 'ABEO', 'q_bid': 207.0, 'px_bid': 5.51, 'px_ask': 5.51, 'q_ask': 100.0, 'v': 21480.0, 'q_op': 63.0, 'c': 5.51, 'pct_change': 2.42}, {'symbol': 'ABEV', 'q_bid': 988.0, 'px_bid': 2.27, 'px_ask': 2.28, 'q_ask': 31792.0, 'v': 33922.0, 'q_op': 40.0, 'c': 2.275, 'pct_change': -1.09}, {'symbol': 'ABG', 'q_bid': 26.0, 'px_bid': 240.34, 'px_ask': 240.6, 'q_ask': 3.0, 'v': 2409.0, 'q_op': 128.0, 'c': 240.58, 'pct_change': -0.26}, {'symbol': 'ABL', 'q_bid': 38.0, 'px_bid': 6.12, 'px_ask': 6.14, 'q_ask': 300.0, 'v': 32256.0, 'q_op': 88.0, 'c': 6.12, 'pct_change': -1.77}, {'symbol': 'ABM', 'q_bid': 8.0, 'px_bid': 45.78, 'px_ask': 45.82, 'q_ask': 43.0, 'v': 9436.0, 'q_op': 131.0, 'c': 45.77, 'pct_change': 1.64}, {'symbol': 'ABNB', 'q_bid': 1.0, 'px_bid': 125.95, 'px_ask': 125.98, 'q_ask': 1.0, 'v': 1469.0, 'q_op': 1438.0, 'c': 125.97, 'pct_change': -0.84}, {'symbol': 'ABR', 'q_bid': 46.0, 'px_bid': 11.74, 'px_ask': 11.75, 'q_ask': 304.0, 'v': 28187.0, 'q_op': 109.0, 'c': 11.725, 'pct_change': -1.22}, {'symbol': 'ABSI', 'q_bid': 1300.0, 'px_bid': 2.71, 'px_ask': 2.72, 'q_ask': 800.0, 'v': 34410.0, 'q_op': 66.0, 'c': 2.725, 'pct_change': 4.41}, {'symbol': 'ABT', 'q_bid': 14.0, 'px_bid': 137.07, 'px_ask': 137.13, 'q_ask': 4.0, 'v': 35939.0, 'q_op': 957.0, 'c': 137.09, 'pct_change': 0.77}, {'symbol': 'ABUS', 'q_bid': 1584.0, 'px_bid': 4.42, 'px_ask': 4.43, 'q_ask': 100.0, 'v': 27273.0, 'q_op': 64.0, 'c': 4.425, 'pct_change': 4.12}, {'symbol': 'ABVX', 'q_bid': 100.0, 'px_bid': 81.19, 'px_ask': 81.8, 'q_ask': 100.0, 'v': 26394.0, 'q_op': 153.0, 'c': 81.87, 'pct_change': -0.52}, {'symbol': 'ACA', 'q_bid': 8.0, 'px_bid': 95.8, 'px_ask': 96.06, 'q_ask': 8.0, 'v': 3315.0, 'q_op': 89.0, 'c': 95.92, 'pct_change': 0.2}, {'symbol': 'ACAD', 'q_bid': 8.0, 'px_bid': 24.7, 'px_ask': 24.7, 'q_ask': 7.0, 'v': 20239.0, 'q_op': 197.0, 'c': 24.7, 'pct_change': 1.15}, {'symbol': 'ACB', 'q_bid': 915.0, 'px_bid': 5.05, 'px_ask': 5.06, 'q_ask': 500.0, 'v': 24446.0, 'q_o ...

# %%
# Assuming data is a list of dictionaries
for item in data:
    print(item)
# Out:
# {'symbol': 'A', 'q_bid': 1.0, 'px_bid': 125.89, 'px_ask': 125.94, 'q_ask': 6.0, 'v': 17156.0, 'q_op': 367.0, 'c': 125.93, 'pct_change': -0.31}
# {'symbol': 'AA', 'q_bid': 35.0, 'px_bid': 32.41, 'px_ask': 32.42, 'q_ask': 100.0, 'v': 11938.0, 'q_op': 711.0, 'c': 32.4, 'pct_change': -0.18}
# {'symbol': 'AAAU', 'q_bid': 35685.0, 'px_bid': 37.0, 'px_ask': 37.01, 'q_ask': 29434.0, 'v': 16004.0, 'q_op': 71.0, 'c': 37.0, 'pct_change': 1.69}
# {'symbol': 'AACG', 'q_bid': 8.0, 'px_bid': 2.33, 'px_ask': 2.45, 'q_ask': 100.0, 'v': 339.0, 'q_op': 6.0, 'c': 2.37, 'pct_change': -3.27}
# {'symbol': 'AAL', 'q_bid': 938.0, 'px_bid': 12.29, 'px_ask': 12.3, 'q_ask': 1530.0, 'v': 19576.0, 'q_op': 429.0, 'c': 12.29, 'pct_change': -1.29}
# {'symbol': 'AAMI', 'q_bid': 136.0, 'px_bid': 48.75, 'px_ask': 48.8, 'q_ask': 1.0, 'v': 7581.0, 'q_op': 99.0, 'c': 48.76, 'pct_change': -0.2}
# {'symbol': 'AAOI', 'q_bid': 226.0, 'px_bid': 30.65, 'px_ask': 30.71, 'q_ask': 63.0, 'v': 15090.0, 'q_op': 567.0, 'c': 30.64, 'pct_change': 5.69}
# {'symbol': 'AAON', 'q_bid': 1.0, 'px_bid': 93.0, 'px_ask': 93.1, 'q_ask': 110.0, 'v': 22844.0, 'q_op': 267.0, 'c': 92.99, 'pct_change': 1.56}
# {'symbol': 'AAP', 'q_bid': 11.0, 'px_bid': 61.06, 'px_ask': 61.1, 'q_ask': 200.0, 'v': 63464.0, 'q_op': 450.0, 'c': 61.03, 'pct_change': 3.97}
# {'symbol': 'AAPL', 'q_bid': 200.0, 'px_bid': 255.13, 'px_ask': 255.15, 'q_ask': 50.0, 'v': 9270.0, 'q_op': 18790.0, 'c': 255.11, 'pct_change': 3.91}
# {'symbol': 'AAT', 'q_bid': 150.0, 'px_bid': 20.81, 'px_ask': 20.82, 'q_ask': 6.0, 'v': 3478.0, 'q_op': 42.0, 'c': 20.79, 'pct_change': 0.19}
# {'symbol': 'ABBV', 'q_bid': 13.0, 'px_bid': 223.34, 'px_ask': 223.46, 'q_ask': 10.0, 'v': 25257.0, 'q_op': 1573.0, 'c': 223.44, 'pct_change': 0.44}
# {'symbol': 'ABCB', 'q_bid': 1.0, 'px_bid': 75.12, 'px_ask': 75.19, 'q_ask': 6.0, 'v': 7240.0, 'q_op': 164.0, 'c': 75.11, 'pct_change': -1.05}
# {'symbol': 'ABCL', 'q_bid': 120.0, 'px_bid': 4.89, 'px_ask': 4.9, 'q_ask': 135.0, 'v': 60943.0, 'q_op': 194.0, 'c': 4.895, 'pct_change': 8.54}
# {'symbol': 'ABEO', 'q_bid': 207.0, 'px_bid': 5.51, 'px_ask': 5.51, 'q_ask': 100.0, 'v': 21480.0, 'q_op': 63.0, 'c': 5.51, 'pct_change': 2.42}
# {'symbol': 'ABEV', 'q_bid': 988.0, 'px_bid': 2.27, 'px_ask': 2.28, 'q_ask': 31792.0, 'v': 33922.0, 'q_op': 40.0, 'c': 2.275, 'pct_change': -1.09}
# {'symbol': 'ABG', 'q_bid': 26.0, 'px_bid': 240.34, 'px_ask': 240.6, 'q_ask': 3.0, 'v': 2409.0, 'q_op': 128.0, 'c': 240.58, 'pct_change': -0.26}
# {'symbol': 'ABL', 'q_bid': 38.0, 'px_bid': 6.12, 'px_ask': 6.14, 'q_ask': 300.0, 'v': 32256.0, 'q_op': 88.0, 'c': 6.12, 'pct_change': -1.77}
# {'symbol': 'ABM', 'q_bid': 8.0, 'px_bid': 45.78, 'px_ask': 45.82, 'q_ask': 43.0, 'v': 9436.0, 'q_op': 131.0, 'c': 45.77, 'pct_change': 1.64}
# {'symbol': 'ABNB', 'q_bid': 1.0, 'px_bid': 125.95, 'px_ask': 125.98, 'q_ask': 1.0, 'v': 1469.0, 'q_op': 1438.0, 'c': 125.97, 'pct_change': -0.84}
# {'symbol': 'ABR', 'q_bid': 46.0, 'px_bid': 11.74, 'px_ask': 11.75, 'q_ask': 304.0, 'v': 28187.0, 'q_op': 109.0, 'c': 11.725, 'pct_change': -1.22}
# {'symbol': 'ABSI', 'q_bid': 1300.0, 'px_bid': 2.71, 'px_ask': 2.72, 'q_ask': 800.0, 'v': 34410.0, 'q_op': 66.0, 'c': 2.725, 'pct_change': 4.41}
# {'symbol': 'ABT', 'q_bid': 14.0, 'px_bid': 137.07, 'px_ask': 137.13, 'q_ask': 4.0, 'v': 35939.0, 'q_op': 957.0, 'c': 137.09, 'pct_change': 0.77}
# {'symbol': 'ABUS', 'q_bid': 1584.0, 'px_bid': 4.42, 'px_ask': 4.43, 'q_ask': 100.0, 'v': 27273.0, 'q_op': 64.0, 'c': 4.425, 'pct_change': 4.12}
# {'symbol': 'ABVX', 'q_bid': 100.0, 'px_bid': 81.19, 'px_ask': 81.8, 'q_ask': 100.0, 'v': 26394.0, 'q_op': 153.0, 'c': 81.87, 'pct_change': -0.52}
# {'symbol': 'ACA', 'q_bid': 8.0, 'px_bid': 95.8, 'px_ask': 96.06, 'q_ask': 8.0, 'v': 3315.0, 'q_op': 89.0, 'c': 95.92, 'pct_change': 0.2}
# {'symbol': 'ACAD', 'q_bid': 8.0, 'px_bid': 24.7, 'px_ask': 24.7, 'q_ask': 7.0, 'v': 20239.0, 'q_op': 197.0, 'c': 24.7, 'pct_change': 1.15}
# {'symbol': 'ACB', 'q_bid': 915.0, 'px_bid': 5.05, 'px_ask': 5.06, 'q_ask': 500.0, 'v': 24446.0, 'q_op': 39.0, 'c': 5.05, 'pct_change': -0.79}
# {'symbol': 'ACCO', 'q_bid': 280.0, 'px_bid': 4.05, 'px_ask': 4.06, 'q_ask': 290.0, 'v': 14598.0, 'q_op': 47.0, 'c': 4.05, 'pct_change': -1.22}
# {'symbol': 'ACDC', 'q_bid': 301.0, 'px_bid': 3.64, 'px_ask': 3.65, 'q_ask': 82.0, 'v': 33568.0, 'q_op': 64.0, 'c': 3.64, 'pct_change': 1.39}
# {'symbol': 'ACEL', 'q_bid': 70.0, 'px_bid': 11.15, 'px_ask': 11.16, 'q_ask': 4.0, 'v': 3463.0, 'q_op': 24.0, 'c': 11.12, 'pct_change': 0.54}
# {'symbol': 'ACGL', 'q_bid': 100.0, 'px_bid': 88.58, 'px_ask': 88.61, 'q_ask': 1.0, 'v': 63031.0, 'q_op': 413.0, 'c': 88.6, 'pct_change': 0.23}
# {'symbol': 'ACHC', 'q_bid': 27.0, 'px_bid': 22.86, 'px_ask': 22.89, 'q_ask': 125.0, 'v': 25395.0, 'q_op': 384.0, 'c': 22.89, 'pct_change': 3.39}
# {'symbol': 'ACHR', 'q_bid': 6170.0, 'px_bid': 9.53, 'px_ask': 9.54, 'q_ask': 735.0, 'v': 40057.0, 'q_op': 599.0, 'c': 9.535, 'pct_change': -3.3}
# {'symbol': 'ACI', 'q_bid': 902.0, 'px_bid': 17.71, 'px_ask': 17.72, 'q_ask': 695.0, 'v': 38089.0, 'q_op': 202.0, 'c': 17.715, 'pct_change': -1.03}
# {'symbol': 'ACIC', 'q_bid': 135.0, 'px_bid': 11.43, 'px_ask': 11.46, 'q_ask': 40.0, 'v': 3592.0, 'q_op': 44.0, 'c': 11.42, 'pct_change': 1.96}
# {'symbol': 'ACIW', 'q_bid': 14.0, 'px_bid': 52.57, 'px_ask': 52.61, 'q_ask': 100.0, 'v': 41798.0, 'q_op': 331.0, 'c': 52.595, 'pct_change': 3.35}
# {'symbol': 'ACLS', 'q_bid': 15.0, 'px_bid': 100.09, 'px_ask': 100.33, 'q_ask': 5.0, 'v': 14861.0, 'q_op': 211.0, 'c': 100.16, 'pct_change': 4.72}
# {'symbol': 'ACLX', 'q_bid': 30.0, 'px_bid': 77.86, 'px_ask': 77.97, 'q_ask': 81.0, 'v': 6729.0, 'q_op': 137.0, 'c': 77.97, 'pct_change': 0.14}
# {'symbol': 'ACM', 'q_bid': 38.0, 'px_bid': 132.78, 'px_ask': 132.88, 'q_ask': 20.0, 'v': 20001.0, 'q_op': 249.0, 'c': 132.82, 'pct_change': 0.26}
# {'symbol': 'ACMR', 'q_bid': 50.0, 'px_bid': 36.68, 'px_ask': 36.74, 'q_ask': 100.0, 'v': 11612.0, 'q_op': 453.0, 'c': 36.655, 'pct_change': 2.13}
# {'symbol': 'ACN', 'q_bid': 12.0, 'px_bid': 239.6, 'px_ask': 239.66, 'q_ask': 10.0, 'v': 38681.0, 'q_op': 1645.0, 'c': 239.72, 'pct_change': 0.01}
# {'symbol': 'ACNB', 'q_bid': 2.0, 'px_bid': 44.51, 'px_ask': 45.0, 'q_ask': 200.0, 'v': 78.0, 'q_op': 12.0, 'c': 44.55, 'pct_change': -1.35}
# {'symbol': 'ACP', 'q_bid': 300.0, 'px_bid': 5.91, 'px_ask': 5.92, 'q_ask': 400.0, 'v': 2763.0, 'q_op': 5.0, 'c': 5.91, 'pct_change': 0.0}
# {'symbol': 'ACT', 'q_bid': 2.0, 'px_bid': 38.38, 'px_ask': 38.41, 'q_ask': 15.0, 'v': 9554.0, 'q_op': 96.0, 'c': 38.38, 'pct_change': -0.16}
# {'symbol': 'ACTG', 'q_bid': 85.0, 'px_bid': 3.25, 'px_ask': 3.26, 'q_ask': 85.0, 'v': 3347.0, 'q_op': 27.0, 'c': 3.26, 'pct_change': -1.51}
# {'symbol': 'ADAM', 'q_bid': 601.0, 'px_bid': 7.29, 'px_ask': 7.31, 'q_ask': 785.0, 'v': 15457.0, 'q_op': 43.0, 'c': 7.31, 'pct_change': -1.08}
# {'symbol': 'ADAP', 'q_bid': 200.0, 'px_bid': 0.168, 'px_ask': 0.169, 'q_ask': 200.0, 'v': 7121.0, 'q_op': 524.0, 'c': 0.168, 'pct_change': 16.41}
# {'symbol': 'ADBE', 'q_bid': 5.0, 'px_bid': 363.04, 'px_ask': 363.27, 'q_ask': 14.0, 'v': 18646.0, 'q_op': 2411.0, 'c': 363.27, 'pct_change': -0.72}
# {'symbol': 'ADC', 'q_bid': 15.0, 'px_bid': 71.12, 'px_ask': 71.14, 'q_ask': 122.0, 'v': 10675.0, 'q_op': 133.0, 'c': 71.13, 'pct_change': -0.13}
# {'symbol': 'ADCT', 'q_bid': 245.0, 'px_bid': 3.4, 'px_ask': 3.41, 'q_ask': 100.0, 'v': 35653.0, 'q_op': 58.0, 'c': 3.415, 'pct_change': -0.15}
# {'symbol': 'ADEA', 'q_bid': 192.0, 'px_bid': 16.91, 'px_ask': 16.93, 'q_ask': 12.0, 'v': 7111.0, 'q_op': 64.0, 'c': 16.92, 'pct_change': 1.68}
# {'symbol': 'ADI', 'q_bid': 7.0, 'px_bid': 247.42, 'px_ask': 247.51, 'q_ask': 17.0, 'v': 61511.0, 'q_op': 1009.0, 'c': 247.465, 'pct_change': 0.87}
# {'symbol': 'ADM', 'q_bid': 135.0, 'px_bid': 59.4, 'px_ask': 59.43, 'q_ask': 200.0, 'v': 9238.0, 'q_op': 791.0, 'c': 59.42, 'pct_change': -3.62}
# {'symbol': 'ADMA', 'q_bid': 10.0, 'px_bid': 15.89, 'px_ask': 15.9, 'q_ask': 18.0, 'v': 37539.0, 'q_op': 196.0, 'c': 15.88, 'pct_change': -0.19}
# {'symbol': 'ADNT', 'q_bid': 16.0, 'px_bid': 24.48, 'px_ask': 24.5, 'q_ask': 35.0, 'v': 13448.0, 'q_op': 116.0, 'c': 24.44, 'pct_change': -0.61}
# {'symbol': 'ADP', 'q_bid': 8.0, 'px_bid': 293.12, 'px_ask': 293.29, 'q_ask': 5.0, 'v': 35172.0, 'q_op': 723.0, 'c': 293.19, 'pct_change': 0.41}
# {'symbol': 'ADPT', 'q_bid': 100.0, 'px_bid': 14.16, 'px_ask': 14.19, 'q_ask': 72.0, 'v': 39784.0, 'q_op': 173.0, 'c': 14.175, 'pct_change': 6.1}
# {'symbol': 'ADSK', 'q_bid': 9.0, 'px_bid': 326.09, 'px_ask': 326.32, 'q_ask': 2.0, 'v': 23698.0, 'q_op': 502.0, 'c': 326.27, 'pct_change': 1.12}
# {'symbol': 'ADT', 'q_bid': 10187.0, 'px_bid': 8.77, 'px_ask': 8.78, 'q_ask': 8510.0, 'v': 56223.0, 'q_op': 121.0, 'c': 8.775, 'pct_change': 2.39}
# {'symbol': 'ADTN', 'q_bid': 43.0, 'px_bid': 9.54, 'px_ask': 9.55, 'q_ask': 100.0, 'v': 28872.0, 'q_op': 101.0, 'c': 9.545, 'pct_change': 0.47}
# {'symbol': 'ADUS', 'q_bid': 100.0, 'px_bid': 112.67, 'px_ask': 113.52, 'q_ask': 5.0, 'v': 4166.0, 'q_op': 113.0, 'c': 113.23, 'pct_change': 1.19}
# {'symbol': 'ADV', 'q_bid': 138.0, 'px_bid': 1.74, 'px_ask': 1.75, 'q_ask': 200.0, 'v': 5511.0, 'q_op': 21.0, 'c': 1.74, 'pct_change': -1.69}
# {'symbol': 'ADX', 'q_bid': 100.0, 'px_bid': 22.37, 'px_ask': 22.55, 'q_ask': 100.0, 'v': 5251.0, 'q_op': 7.0, 'c': 22.46, 'pct_change': 0.31}
# {'symbol': 'AEBI', 'q_bid': 55.0, 'px_bid': 13.11, 'px_ask': 13.25, 'q_ask': 300.0, 'v': 21914.0, 'q_op': 69.0, 'c': 13.15, 'pct_change': 5.28}
# {'symbol': 'AEE', 'q_bid': 6.0, 'px_bid': 99.39, 'px_ask': 99.45, 'q_ask': 94.0, 'v': 13855.0, 'q_op': 352.0, 'c': 99.4, 'pct_change': 0.27}
# {'symbol': 'AEG', 'q_bid': 26361.0, 'px_bid': 7.9, 'px_ask': 7.91, 'q_ask': 7500.0, 'v': 705.0, 'q_op': 41.0, 'c': 7.91, 'pct_change': 1.41}
# {'symbol': 'AEHR', 'q_bid': 100.0, 'px_bid': 32.2, 'px_ask': 32.4, 'q_ask': 60.0, 'v': 51418.0, 'q_op': 261.0, 'c': 32.13, 'pct_change': 7.28}
# {'symbol': 'AEI', 'q_bid': 200.0, 'px_bid': 3.28, 'px_ask': 3.37, 'q_ask': 142.0, 'v': 1913.0, 'q_op': 10.0, 'c': 3.385, 'pct_change': -2.45}
# {'symbol': 'AEIS', 'q_bid': 7.0, 'px_bid': 173.72, 'px_ask': 173.9, 'q_ask': 1.0, 'v': 14048.0, 'q_op': 293.0, 'c': 173.87, 'pct_change': -0.28}
# {'symbol': 'AEMD', 'q_bid': 100.0, 'px_bid': 0.747, 'px_ask': 0.788, 'q_ask': 100.0, 'v': 1411.0, 'q_op': 13.0, 'c': 0.75, 'pct_change': 3.08}
# {'symbol': 'AEO', 'q_bid': 200.0, 'px_bid': 18.09, 'px_ask': 18.1, 'q_ask': 307.0, 'v': 58872.0, 'q_op': 681.0, 'c': 18.095, 'pct_change': -4.11}
# {'symbol': 'AEP', 'q_bid': 20.0, 'px_bid': 107.18, 'px_ask': 107.2, 'q_ask': 30.0, 'v': 43431.0, 'q_op': 598.0, 'c': 107.17, 'pct_change': 0.1}
# {'symbol': 'AES', 'q_bid': 205.0, 'px_bid': 13.11, 'px_ask': 13.12, 'q_ask': 501.0, 'v': 18677.0, 'q_op': 239.0, 'c': 13.115, 'pct_change': 0.5}
# {'symbol': 'AESI', 'q_bid': 7.0, 'px_bid': 11.19, 'px_ask': 11.2, 'q_ask': 100.0, 'v': 29295.0, 'q_op': 98.0, 'c': 11.2, 'pct_change': 3.13}
# {'symbol': 'AEVA', 'q_bid': 1.0, 'px_bid': 18.23, 'px_ask': 18.3, 'q_ask': 3.0, 'v': 27144.0, 'q_op': 258.0, 'c': 18.35, 'pct_change': 0.38}
# {'symbol': 'AFG', 'q_bid': 1.0, 'px_bid': 142.04, 'px_ask': 142.2, 'q_ask': 15.0, 'v': 6019.0, 'q_op': 175.0, 'c': 142.2, 'pct_change': 0.66}
# {'symbol': 'AFL', 'q_bid': 2.0, 'px_bid': 107.57, 'px_ask': 107.61, 'q_ask': 26.0, 'v': 27346.0, 'q_op': 539.0, 'c': 107.61, 'pct_change': -0.4}
# {'symbol': 'AFRM', 'q_bid': 100.0, 'px_bid': 89.78, 'px_ask': 89.83, 'q_ask': 50.0, 'v': 54513.0, 'q_op': 1515.0, 'c': 89.78, 'pct_change': -2.6}
# {'symbol': 'AG', 'q_bid': 6100.0, 'px_bid': 12.11, 'px_ask': 12.12, 'q_ask': 2735.0, 'v': 12619.0, 'q_op': 1093.0, 'c': 12.115, 'pct_change': 14.08}
# {'symbol': 'AGCO', 'q_bid': 7.0, 'px_bid': 110.0, 'px_ask': 110.13, 'q_ask': 5.0, 'v': 11748.0, 'q_op': 184.0, 'c': 110.1, 'pct_change': 0.4}
# {'symbol': 'AGI', 'q_bid': 350.0, 'px_bid': 33.2, 'px_ask': 33.21, 'q_ask': 210.0, 'v': 30340.0, 'q_op': 640.0, 'c': 33.215, 'pct_change': 2.71}
# {'symbol': 'AGIO', 'q_bid': 1.0, 'px_bid': 38.59, 'px_ask': 38.67, 'q_ask': 110.0, 'v': 12957.0, 'q_op': 149.0, 'c': 38.64, 'pct_change': 2.49}
# {'symbol': 'AGL', 'q_bid': 6059.0, 'px_bid': 1.14, 'px_ask': 1.15, 'q_ask': 2204.0, 'v': 21935.0, 'q_op': 29.0, 'c': 1.145, 'pct_change': -1.29}
# {'symbol': 'AGM', 'q_bid': 6.0, 'px_bid': 180.76, 'px_ask': 181.91, 'q_ask': 100.0, 'v': 677.0, 'q_op': 48.0, 'c': 181.04, 'pct_change': -1.39}
# {'symbol': 'AGNC', 'q_bid': 9558.0, 'px_bid': 9.76, 'px_ask': 9.77, 'q_ask': 16697.0, 'v': 13166.0, 'q_op': 148.0, 'c': 9.765, 'pct_change': -2.06}
# {'symbol': 'AGO', 'q_bid': 1.0, 'px_bid': 83.68, 'px_ask': 83.65, 'q_ask': 6.0, 'v': 3831.0, 'q_op': 76.0, 'c': 83.65, 'pct_change': 0.02}
# {'symbol': 'AGRO', 'q_bid': 436.0, 'px_bid': 8.18, 'px_ask': 8.19, 'q_ask': 100.0, 'v': 22961.0, 'q_op': 43.0, 'c': 8.19, 'pct_change': 3.67}
# {'symbol': 'AGX', 'q_bid': 5.0, 'px_bid': 264.82, 'px_ask': 265.58, 'q_ask': 1.0, 'v': 9606.0, 'q_op': 181.0, 'c': 265.56, 'pct_change': 1.89}
# {'symbol': 'AGYS', 'q_bid': 1.0, 'px_bid': 106.26, 'px_ask': 106.41, 'q_ask': 10.0, 'v': 7112.0, 'q_op': 146.0, 'c': 106.37, 'pct_change': 0.71}
# {'symbol': 'AHCO', 'q_bid': 200.0, 'px_bid': 8.88, 'px_ask': 8.9, 'q_ask': 5.0, 'v': 18653.0, 'q_op': 84.0, 'c': 8.88, 'pct_change': -0.11}
# {'symbol': 'AHH', 'q_bid': 232.0, 'px_bid': 7.29, 'px_ask': 7.31, 'q_ask': 100.0, 'v': 14382.0, 'q_op': 60.0, 'c': 7.285, 'pct_change': -1.15}
# {'symbol': 'AHL', 'q_bid': 100.0, 'px_bid': 36.68, 'px_ask': 36.7, 'q_ask': 105.0, 'v': 9806.0, 'q_op': 40.0, 'c': 36.69, 'pct_change': 0.11}
# {'symbol': 'AHR', 'q_bid': 1.0, 'px_bid': 42.19, 'px_ask': 42.22, 'q_ask': 4.0, 'v': 13682.0, 'q_op': 213.0, 'c': 42.2, 'pct_change': -0.05}
# {'symbol': 'AHT', 'q_bid': 100.0, 'px_bid': 5.89, 'px_ask': 6.03, 'q_ask': 100.0, 'v': 21.0, 'q_op': 1.0, 'c': 5.92, 'pct_change': 0.0}
# {'symbol': 'AI', 'q_bid': 150.0, 'px_bid': 18.74, 'px_ask': 18.76, 'q_ask': 336.0, 'v': 18990.0, 'q_op': 561.0, 'c': 18.77, 'pct_change': 4.86}
# {'symbol': 'AIG', 'q_bid': 23.0, 'px_bid': 76.42, 'px_ask': 76.43, 'q_ask': 102.0, 'v': 26161.0, 'q_op': 492.0, 'c': 76.42, 'pct_change': -0.73}
# {'symbol': 'AII', 'q_bid': 10.0, 'px_bid': 22.4, 'px_ask': 22.72, 'q_ask': 100.0, 'v': 1464.0, 'q_op': 22.0, 'c': 22.26, 'pct_change': 3.49}
# {'symbol': 'AIN', 'q_bid': 5.0, 'px_bid': 56.15, 'px_ask': 56.21, 'q_ask': 8.0, 'v': 4831.0, 'q_op': 94.0, 'c': 56.14, 'pct_change': -0.34}
# {'symbol': 'AIOT', 'q_bid': 100.0, 'px_bid': 5.38, 'px_ask': 5.39, 'q_ask': 200.0, 'v': 17977.0, 'q_op': 52.0, 'c': 5.375, 'pct_change': 0.66}
# {'symbol': 'AIP', 'q_bid': 1.0, 'px_bid': 10.46, 'px_ask': 10.5, 'q_ask': 1.0, 'v': 25836.0, 'q_op': 100.0, 'c': 10.48, 'pct_change': 6.18}
# {'symbol': 'AIQ', 'q_bid': 1000.0, 'px_bid': 49.67, 'px_ask': 49.68, 'q_ask': 504.0, 'v': 45066.0, 'q_op': 179.0, 'c': 49.675, 'pct_change': 1.09}
# {'symbol': 'AIR', 'q_bid': 100.0, 'px_bid': 77.19, 'px_ask': 77.29, 'q_ask': 18.0, 'v': 17477.0, 'q_op': 169.0, 'c': 77.23, 'pct_change': 2.56}
# {'symbol': 'AIRO', 'q_bid': 20.0, 'px_bid': 20.21, 'px_ask': 20.27, 'q_ask': 14.0, 'v': 32231.0, 'q_op': 106.0, 'c': 20.27, 'pct_change': 3.79}
# {'symbol': 'AIRS', 'q_bid': 700.0, 'px_bid': 6.75, 'px_ask': 6.79, 'q_ask': 100.0, 'v': 25257.0, 'q_op': 78.0, 'c': 6.78, 'pct_change': 3.51}
# {'symbol': 'AIT', 'q_bid': 28.0, 'px_bid': 265.61, 'px_ask': 265.9, 'q_ask': 112.0, 'v': 6650.0, 'q_op': 183.0, 'c': 265.7, 'pct_change': 2.02}
# {'symbol': 'AIV', 'q_bid': 323.0, 'px_bid': 7.82, 'px_ask': 7.83, 'q_ask': 100.0, 'v': 23046.0, 'q_op': 60.0, 'c': 7.815, 'pct_change': -0.45}
# {'symbol': 'AIZ', 'q_bid': 2.0, 'px_bid': 210.58, 'px_ask': 210.95, 'q_ask': 12.0, 'v': 7785.0, 'q_op': 169.0, 'c': 210.56, 'pct_change': 0.46}
# {'symbol': 'AJG', 'q_bid': 52.0, 'px_bid': 299.27, 'px_ask': 299.57, 'q_ask': 17.0, 'v': 31990.0, 'q_op': 528.0, 'c': 299.51, 'pct_change': -0.05}
# {'symbol': 'AKAM', 'q_bid': 1.0, 'px_bid': 76.7, 'px_ask': 76.73, 'q_ask': 1.0, 'v': 20185.0, 'q_op': 384.0, 'c': 76.72, 'pct_change': 0.58}
# {'symbol': 'AKBA', 'q_bid': 2454.0, 'px_bid': 2.8, 'px_ask': 2.81, 'q_ask': 858.0, 'v': 7649.0, 'q_op': 50.0, 'c': 2.805, 'pct_change': -0.53}
# {'symbol': 'AKR', 'q_bid': 81.0, 'px_bid': 20.13, 'px_ask': 20.15, 'q_ask': 7.0, 'v': 12196.0, 'q_op': 85.0, 'c': 20.12, 'pct_change': -0.84}
# {'symbol': 'AKRO', 'q_bid': 11.0, 'px_bid': 46.18, 'px_ask': 46.23, 'q_ask': 105.0, 'v': 21585.0, 'q_op': 314.0, 'c': 46.23, 'pct_change': 2.23}
# {'symbol': 'AL', 'q_bid': 246.0, 'px_bid': 63.52, 'px_ask': 63.53, 'q_ask': 404.0, 'v': 18448.0, 'q_op': 65.0, 'c': 63.52, 'pct_change': -0.14}
# {'symbol': 'ALAB', 'q_bid': 16.0, 'px_bid': 236.57, 'px_ask': 236.98, 'q_ask': 11.0, 'v': 9561.0, 'q_op': 2439.0, 'c': 236.75, 'pct_change': -3.45}
# {'symbol': 'ALAR', 'q_bid': 100.0, 'px_bid': 16.22, 'px_ask': 16.54, 'q_ask': 100.0, 'v': 242.0, 'q_op': 4.0, 'c': 16.375, 'pct_change': -1.68}
# {'symbol': 'ALB', 'q_bid': 2.0, 'px_bid': 81.69, 'px_ask': 81.76, 'q_ask': 10.0, 'v': 1934.0, 'q_op': 769.0, 'c': 81.75, 'pct_change': -0.11}
# {'symbol': 'ALC', 'q_bid': 5.0, 'px_bid': 77.77, 'px_ask': 77.79, 'q_ask': 46.0, 'v': 43421.0, 'q_op': 239.0, 'c': 77.79, 'pct_change': 0.7}
# {'symbol': 'ALDX', 'q_bid': 45.0, 'px_bid': 4.95, 'px_ask': 4.97, 'q_ask': 100.0, 'v': 30329.0, 'q_op': 71.0, 'c': 4.965, 'pct_change': 0.71}
# {'symbol': 'ALE', 'q_bid': 62.0, 'px_bid': 63.99, 'px_ask': 64.04, 'q_ask': 25.0, 'v': 10221.0, 'q_op': 86.0, 'c': 63.89, 'pct_change': -0.17}
# {'symbol': 'ALEX', 'q_bid': 4.0, 'px_bid': 18.27, 'px_ask': 18.33, 'q_ask': 1.0, 'v': 4964.0, 'q_op': 34.0, 'c': 18.29, 'pct_change': -0.44}
# {'symbol': 'ALG', 'q_bid': 1.0, 'px_bid': 199.09, 'px_ask': 200.36, 'q_ask': 4.0, 'v': 3845.0, 'q_op': 273.0, 'c': 198.93, 'pct_change': 0.24}
# {'symbol': 'ALGM', 'q_bid': 7.0, 'px_bid': 31.83, 'px_ask': 31.86, 'q_ask': 9.0, 'v': 19153.0, 'q_op': 200.0, 'c': 31.84, 'pct_change': 1.24}
# {'symbol': 'ALGN', 'q_bid': 6.0, 'px_bid': 131.29, 'px_ask': 131.39, 'q_ask': 7.0, 'v': 18286.0, 'q_op': 419.0, 'c': 131.33, 'pct_change': -0.05}
# {'symbol': 'ALGT', 'q_bid': 4.0, 'px_bid': 61.49, 'px_ask': 61.57, 'q_ask': 8.0, 'v': 9950.0, 'q_op': 151.0, 'c': 61.62, 'pct_change': 1.02}
# {'symbol': 'ALHC', 'q_bid': 112.0, 'px_bid': 16.84, 'px_ask': 16.86, 'q_ask': 25.0, 'v': 783.0, 'q_op': 179.0, 'c': 16.84, 'pct_change': 1.81}
# {'symbol': 'ALIT', 'q_bid': 13317.0, 'px_bid': 3.34, 'px_ask': 3.35, 'q_ask': 3031.0, 'v': 65513.0, 'q_op': 84.0, 'c': 3.345, 'pct_change': 0.15}
# {'symbol': 'ALK', 'q_bid': 105.0, 'px_bid': 54.69, 'px_ask': 54.75, 'q_ask': 10.0, 'v': 63727.0, 'q_op': 703.0, 'c': 54.74, 'pct_change': -4.38}
# {'symbol': 'ALKS', 'q_bid': 100.0, 'px_bid': 27.93, 'px_ask': 27.97, 'q_ask': 105.0, 'v': 38911.0, 'q_op': 199.0, 'c': 27.96, 'pct_change': 0.61}
# {'symbol': 'ALKT', 'q_bid': 2.0, 'px_bid': 25.57, 'px_ask': 25.59, 'q_ask': 62.0, 'v': 18668.0, 'q_op': 140.0, 'c': 25.55, 'pct_change': 1.03}
# {'symbol': 'ALL', 'q_bid': 2.0, 'px_bid': 206.74, 'px_ask': 206.79, 'q_ask': 5.0, 'v': 28095.0, 'q_op': 490.0, 'c': 206.75, 'pct_change': 0.34}
# {'symbol': 'ALLE', 'q_bid': 3.0, 'px_bid': 177.88, 'px_ask': 177.93, 'q_ask': 101.0, 'v': 18896.0, 'q_op': 388.0, 'c': 177.905, 'pct_change': -0.79}
# {'symbol': 'ALLT', 'q_bid': 105.0, 'px_bid': 10.17, 'px_ask': 10.22, 'q_ask': 100.0, 'v': 11498.0, 'q_op': 56.0, 'c': 10.22, 'pct_change': 3.97}
# {'symbol': 'ALLY', 'q_bid': 300.0, 'px_bid': 43.28, 'px_ask': 43.29, 'q_ask': 229.0, 'v': 20253.0, 'q_op': 407.0, 'c': 43.29, 'pct_change': -2.08}
# {'symbol': 'ALM', 'q_bid': 200.0, 'px_bid': 5.32, 'px_ask': 5.33, 'q_ask': 213.0, 'v': 63769.0, 'q_op': 72.0, 'c': 5.32, 'pct_change': 4.93}
# {'symbol': 'ALMS', 'q_bid': 600.0, 'px_bid': 4.11, 'px_ask': 4.16, 'q_ask': 264.0, 'v': 9017.0, 'q_op': 39.0, 'c': 4.14, 'pct_change': -0.72}
# {'symbol': 'ALNY', 'q_bid': 5.0, 'px_bid': 459.78, 'px_ask': 460.25, 'q_ask': 18.0, 'v': 17193.0, 'q_op': 414.0, 'c': 460.04, 'pct_change': 1.43}
# {'symbol': 'ALRM', 'q_bid': 200.0, 'px_bid': 56.0, 'px_ask': 55.99, 'q_ask': 6.0, 'v': 12818.0, 'q_op': 174.0, 'c': 55.96, 'pct_change': 1.14}
# {'symbol': 'ALRS', 'q_bid': 100.0, 'px_bid': 22.88, 'px_ask': 23.01, 'q_ask': 2.0, 'v': 1629.0, 'q_op': 30.0, 'c': 22.98, 'pct_change': -0.65}
# {'symbol': 'ALSN', 'q_bid': 2.0, 'px_bid': 88.58, 'px_ask': 88.65, 'q_ask': 3.0, 'v': 8500.0, 'q_op': 185.0, 'c': 88.62, 'pct_change': 0.36}
# {'symbol': 'ALT', 'q_bid': 700.0, 'px_bid': 3.96, 'px_ask': 3.97, 'q_ask': 414.0, 'v': 47654.0, 'q_op': 79.0, 'c': 3.97, 'pct_change': 5.03}
# {'symbol': 'ALTI', 'q_bid': 100.0, 'px_bid': 3.76, 'px_ask': 3.86, 'q_ask': 203.0, 'v': 15685.0, 'q_op': 193.0, 'c': 3.79, 'pct_change': -2.32}
# {'symbol': 'ALTO', 'q_bid': 100.0, 'px_bid': 1.08, 'px_ask': 1.09, 'q_ask': 500.0, 'v': 18553.0, 'q_op': 25.0, 'c': 1.08, 'pct_change': 17.75}
# {'symbol': 'ALTS', 'q_bid': 2400.0, 'px_bid': 3.78, 'px_ask': 3.8, 'q_ask': 500.0, 'v': 25231.0, 'q_op': 133.0, 'c': 3.805, 'pct_change': -2.44}
# {'symbol': 'ALVO', 'q_bid': 9.0, 'px_bid': 8.0, 'px_ask': 8.05, 'q_ask': 300.0, 'v': 7829.0, 'q_op': 39.0, 'c': 7.99, 'pct_change': 1.4}
# {'symbol': 'ALX', 'q_bid': 1.0, 'px_bid': 231.71, 'px_ask': 232.16, 'q_ask': 1.0, 'v': 515.0, 'q_op': 93.0, 'c': 231.45, 'pct_change': -0.37}
# {'symbol': 'ALZN', 'q_bid': 100.0, 'px_bid': 2.31, 'px_ask': 2.41, 'q_ask': 200.0, 'v': 352.0, 'q_op': 3.0, 'c': 2.34, 'pct_change': -2.5}
# {'symbol': 'AM', 'q_bid': 1.0, 'px_bid': 18.71, 'px_ask': 18.72, 'q_ask': 361.0, 'v': 39969.0, 'q_op': 155.0, 'c': 18.71, 'pct_change': 0.81}
# {'symbol': 'AMAT', 'q_bid': 1.0, 'px_bid': 200.61, 'px_ask': 200.74, 'q_ask': 97.0, 'v': 40467.0, 'q_op': 3974.0, 'c': 200.605, 'pct_change': 5.53}
# {'symbol': 'AMBA', 'q_bid': 71.0, 'px_bid': 88.71, 'px_ask': 88.81, 'q_ask': 2.0, 'v': 32942.0, 'q_op': 350.0, 'c': 88.8, 'pct_change': 7.08}
# {'symbol': 'AMBC', 'q_bid': 40.0, 'px_bid': 9.16, 'px_ask': 9.21, 'q_ask': 500.0, 'v': 11279.0, 'q_op': 49.0, 'c': 9.17, 'pct_change': 0.55}
# {'symbol': 'AMBP', 'q_bid': 1361.0, 'px_bid': 3.95, 'px_ask': 3.96, 'q_ask': 600.0, 'v': 60964.0, 'q_op': 66.0, 'c': 3.955, 'pct_change': 2.46}
# {'symbol': 'AMC', 'q_bid': 8193.0, 'px_bid': 2.97, 'px_ask': 2.98, 'q_ask': 5100.0, 'v': 54974.0, 'q_op': 126.0, 'c': 2.975, 'pct_change': -1.16}
# {'symbol': 'AMCR', 'q_bid': 5545.0, 'px_bid': 8.25, 'px_ask': 8.26, 'q_ask': 9806.0, 'v': 20668.0, 'q_op': 153.0, 'c': 8.25, 'pct_change': -0.12}
# {'symbol': 'AMD', 'q_bid': 100.0, 'px_bid': 160.28, 'px_ask': 160.29, 'q_ask': 212.0, 'v': 53435.0, 'q_op': 8156.0, 'c': 160.29, 'pct_change': 1.84}
# {'symbol': 'AMDL', 'q_bid': 12179.0, 'px_bid': 10.16, 'px_ask': 10.17, 'q_ask': 22208.0, 'v': 22027.0, 'q_op': 562.0, 'c': 10.16, 'pct_change': 3.78}
# {'symbol': 'AME', 'q_bid': 10.0, 'px_bid': 188.59, 'px_ask': 188.67, 'q_ask': 2.0, 'v': 12799.0, 'q_op': 281.0, 'c': 188.65, 'pct_change': 0.42}
# {'symbol': 'AMG', 'q_bid': 10.0, 'px_bid': 242.99, 'px_ask': 243.35, 'q_ask': 9.0, 'v': 3902.0, 'q_op': 150.0, 'c': 242.81, 'pct_change': -0.02}
# {'symbol': 'AMGN', 'q_bid': 291.0, 'px_bid': 286.37, 'px_ask': 286.53, 'q_ask': 6.0, 'v': 32838.0, 'q_op': 1227.0, 'c': 286.49, 'pct_change': 0.38}
# {'symbol': 'AMH', 'q_bid': 47.0, 'px_bid': 33.36, 'px_ask': 33.38, 'q_ask': 213.0, 'v': 54490.0, 'q_op': 277.0, 'c': 33.365, 'pct_change': -0.19}
# {'symbol': 'AMKR', 'q_bid': 30.0, 'px_bid': 29.63, 'px_ask': 29.65, 'q_ask': 100.0, 'v': 37978.0, 'q_op': 634.0, 'c': 29.64, 'pct_change': 4.7}
# {'symbol': 'AMLP', 'q_bid': 100.0, 'px_bid': 46.54, 'px_ask': 46.55, 'q_ask': 439.0, 'v': 6263.0, 'q_op': 97.0, 'c': 46.505, 'pct_change': -0.88}
# {'symbol': 'AMLX', 'q_bid': 1.0, 'px_bid': 13.41, 'px_ask': 13.44, 'q_ask': 6.0, 'v': 24268.0, 'q_op': 143.0, 'c': 13.45, 'pct_change': 1.05}
# {'symbol': 'AMN', 'q_bid': 10.0, 'px_bid': 19.07, 'px_ask': 19.11, 'q_ask': 39.0, 'v': 12601.0, 'q_op': 112.0, 'c': 19.06, 'pct_change': 1.82}
# {'symbol': 'AMP', 'q_bid': 72.0, 'px_bid': 492.91, 'px_ask': 493.23, 'q_ask': 31.0, 'v': 16694.0, 'q_op': 394.0, 'c': 492.85, 'pct_change': 0.68}
# {'symbol': 'AMPH', 'q_bid': 6.0, 'px_bid': 27.94, 'px_ask': 27.97, 'q_ask': 43.0, 'v': 9685.0, 'q_op': 120.0, 'c': 27.92, 'pct_change': 1.01}
# {'symbol': 'AMPL', 'q_bid': 6.0, 'px_bid': 12.35, 'px_ask': 12.37, 'q_ask': 20.0, 'v': 24224.0, 'q_op': 130.0, 'c': 12.37, 'pct_change': 2.49}
# {'symbol': 'AMPX', 'q_bid': 5.0, 'px_bid': 11.86, 'px_ask': 11.87, 'q_ask': 162.0, 'v': 19934.0, 'q_op': 512.0, 'c': 11.86, 'pct_change': 0.76}
# {'symbol': 'AMR', 'q_bid': 4.0, 'px_bid': 162.03, 'px_ask': 162.52, 'q_ask': 6.0, 'v': 6889.0, 'q_op': 183.0, 'c': 162.14, 'pct_change': -2.38}
# {'symbol': 'AMRC', 'q_bid': 19.0, 'px_bid': 32.16, 'px_ask': 32.19, 'q_ask': 8.0, 'v': 12314.0, 'q_op': 114.0, 'c': 32.19, 'pct_change': 4.48}
# {'symbol': 'AMRX', 'q_bid': 36.0, 'px_bid': 9.99, 'px_ask': 10.0, 'q_ask': 515.0, 'v': 46531.0, 'q_op': 112.0, 'c': 9.99, 'pct_change': 1.83}
# {'symbol': 'AMRZ', 'q_bid': 16.0, 'px_bid': 50.2, 'px_ask': 50.22, 'q_ask': 90.0, 'v': 27400.0, 'q_op': 388.0, 'c': 50.19, 'pct_change': -0.42}
# {'symbol': 'AMSC', 'q_bid': 7.0, 'px_bid': 64.64, 'px_ask': 64.71, 'q_ask': 7.0, 'v': 24121.0, 'q_op': 380.0, 'c': 64.76, 'pct_change': 5.22}
# {'symbol': 'AMSF', 'q_bid': 43.0, 'px_bid': 44.12, 'px_ask': 44.21, 'q_ask': 12.0, 'v': 3610.0, 'q_op': 51.0, 'c': 44.13, 'pct_change': 0.55}
# {'symbol': 'AMT', 'q_bid': 9.0, 'px_bid': 193.31, 'px_ask': 193.4, 'q_ask': 11.0, 'v': 1730.0, 'q_op': 844.0, 'c': 193.38, 'pct_change': 0.04}
# {'symbol': 'AMTM', 'q_bid': 6.0, 'px_bid': 22.61, 'px_ask': 22.62, 'q_ask': 28.0, 'v': 26803.0, 'q_op': 172.0, 'c': 22.62, 'pct_change': 1.21}
# {'symbol': 'AMWD', 'q_bid': 100.0, 'px_bid': 65.0, 'px_ask': 65.02, 'q_ask': 101.0, 'v': 10804.0, 'q_op': 191.0, 'c': 64.97, 'pct_change': -2.08}
# {'symbol': 'AMZN', 'q_bid': 56.0, 'px_bid': 228.0, 'px_ask': 228.02, 'q_ask': 11.0, 'v': 45820.0, 'q_op': 7711.0, 'c': 228.01, 'pct_change': -1.5}
# {'symbol': 'AN', 'q_bid': 3.0, 'px_bid': 218.89, 'px_ask': 219.06, 'q_ask': 5.0, 'v': 8922.0, 'q_op': 260.0, 'c': 219.005, 'pct_change': 0.54}
# {'symbol': 'ANAB', 'q_bid': 160.0, 'px_bid': 21.39, 'px_ask': 21.52, 'q_ask': 100.0, 'v': 7579.0, 'q_op': 84.0, 'c': 21.42, 'pct_change': 2.78}
# {'symbol': 'ANDE', 'q_bid': 7.0, 'px_bid': 38.29, 'px_ask': 38.37, 'q_ask': 100.0, 'v': 12512.0, 'q_op': 142.0, 'c': 38.35, 'pct_change': -0.72}
# {'symbol': 'ANET', 'q_bid': 7.0, 'px_bid': 145.72, 'px_ask': 145.8, 'q_ask': 7.0, 'v': 30531.0, 'q_op': 2402.0, 'c': 145.77, 'pct_change': -2.57}
# {'symbol': 'ANF', 'q_bid': 1.0, 'px_bid': 87.43, 'px_ask': 87.53, 'q_ask': 75.0, 'v': 63790.0, 'q_op': 507.0, 'c': 87.42, 'pct_change': -3.83}
# {'symbol': 'ANGI', 'q_bid': 134.0, 'px_bid': 17.01, 'px_ask': 17.02, 'q_ask': 100.0, 'v': 25942.0, 'q_op': 163.0, 'c': 17.02, 'pct_change': -5.86}
# {'symbol': 'ANGL', 'q_bid': 1100.0, 'px_bid': 29.72, 'px_ask': 29.73, 'q_ask': 600.0, 'v': 5894.0, 'q_op': 14.0, 'c': 29.725, 'pct_change': 0.05}
# {'symbol': 'ANGO', 'q_bid': 10.0, 'px_bid': 10.78, 'px_ask': 10.8, 'q_ask': 59.0, 'v': 9907.0, 'q_op': 58.0, 'c': 10.75, 'pct_change': -0.19}
# {'symbol': 'ANIP', 'q_bid': 61.0, 'px_bid': 95.96, 'px_ask': 96.29, 'q_ask': 3.0, 'v': 6221.0, 'q_op': 97.0, 'c': 96.1, 'pct_change': -0.71}
# {'symbol': 'ANRO', 'q_bid': 100.0, 'px_bid': 3.86, 'px_ask': 3.91, 'q_ask': 26.0, 'v': 754.0, 'q_op': 11.0, 'c': 3.86, 'pct_change': 7.22}
# {'symbol': 'ANY', 'q_bid': 500.0, 'px_bid': 0.67, 'px_ask': 0.684, 'q_ask': 100.0, 'v': 7774.0, 'q_op': 28.0, 'c': 0.676, 'pct_change': -0.37}
# {'symbol': 'AOD', 'q_bid': 100.0, 'px_bid': 9.48, 'px_ask': 9.49, 'q_ask': 100.0, 'v': 3189.0, 'q_op': 7.0, 'c': 9.485, 'pct_change': 0.26}
# {'symbol': 'AON', 'q_bid': 16.0, 'px_bid': 353.14, 'px_ask': 353.25, 'q_ask': 7.0, 'v': 19087.0, 'q_op': 409.0, 'c': 353.23, 'pct_change': 0.54}
# {'symbol': 'AOS', 'q_bid': 44.0, 'px_bid': 72.35, 'px_ask': 72.39, 'q_ask': 14.0, 'v': 15914.0, 'q_op': 242.0, 'c': 72.35, 'pct_change': -1.01}
# {'symbol': 'AOSL', 'q_bid': 5.0, 'px_bid': 30.32, 'px_ask': 30.39, 'q_ask': 400.0, 'v': 4505.0, 'q_op': 74.0, 'c': 30.39, 'pct_change': 6.18}
# {'symbol': 'APA', 'q_bid': 25.0, 'px_bid': 23.74, 'px_ask': 23.76, 'q_ask': 300.0, 'v': 16922.0, 'q_op': 560.0, 'c': 23.79, 'pct_change': 1.32}
# {'symbol': 'APAM', 'q_bid': 8.0, 'px_bid': 45.37, 'px_ask': 45.42, 'q_ask': 14.0, 'v': 5839.0, 'q_op': 98.0, 'c': 45.4, 'pct_change': -0.72}
# {'symbol': 'APD', 'q_bid': 11.0, 'px_bid': 290.41, 'px_ask': 290.65, 'q_ask': 100.0, 'v': 14715.0, 'q_op': 330.0, 'c': 290.64, 'pct_change': 0.17}
# {'symbol': 'APEI', 'q_bid': 18.0, 'px_bid': 36.37, 'px_ask': 36.45, 'q_ask': 401.0, 'v': 3812.0, 'q_op': 49.0, 'c': 36.43, 'pct_change': 1.42}
# {'symbol': 'APG', 'q_bid': 312.0, 'px_bid': 35.17, 'px_ask': 35.18, 'q_ask': 102.0, 'v': 29971.0, 'q_op': 188.0, 'c': 35.15, 'pct_change': 0.57}
# {'symbol': 'APGE', 'q_bid': 4.0, 'px_bid': 37.66, 'px_ask': 37.94, 'q_ask': 100.0, 'v': 9847.0, 'q_op': 132.0, 'c': 37.76, 'pct_change': 3.37}
# {'symbol': 'APH', 'q_bid': 104.0, 'px_bid': 123.54, 'px_ask': 123.59, 'q_ask': 20.0, 'v': 39461.0, 'q_op': 1398.0, 'c': 123.56, 'pct_change': -0.31}
# {'symbol': 'APLD', 'q_bid': 200.0, 'px_bid': 24.47, 'px_ask': 24.48, 'q_ask': 100.0, 'v': 36522.0, 'q_op': 2333.0, 'c': 24.435, 'pct_change': 19.31}
# {'symbol': 'APLE', 'q_bid': 100.0, 'px_bid': 12.32, 'px_ask': 12.33, 'q_ask': 200.0, 'v': 32895.0, 'q_op': 84.0, 'c': 12.32, 'pct_change': -1.44}
# {'symbol': 'APLS', 'q_bid': 116.0, 'px_bid': 23.35, 'px_ask': 23.4, 'q_ask': 31.0, 'v': 32759.0, 'q_op': 236.0, 'c': 23.38, 'pct_change': 1.61}
# {'symbol': 'APO', 'q_bid': 11.0, 'px_bid': 143.53, 'px_ask': 143.57, 'q_ask': 10.0, 'v': 15948.0, 'q_op': 781.0, 'c': 143.59, 'pct_change': -0.8}
# {'symbol': 'APOG', 'q_bid': 10.0, 'px_bid': 45.11, 'px_ask': 45.26, 'q_ask': 1.0, 'v': 8391.0, 'q_op': 144.0, 'c': 45.23, 'pct_change': 3.17}
# {'symbol': 'APP', 'q_bid': 150.0, 'px_bid': 644.27, 'px_ask': 644.81, 'q_ask': 36.0, 'v': 48284.0, 'q_op': 3430.0, 'c': 644.12, 'pct_change': -0.84}
# {'symbol': 'APPF', 'q_bid': 4.0, 'px_bid': 282.22, 'px_ask': 282.42, 'q_ask': 1.0, 'v': 5627.0, 'q_op': 155.0, 'c': 282.46, 'pct_change': 0.32}
# {'symbol': 'APPN', 'q_bid': 1.0, 'px_bid': 33.75, 'px_ask': 33.82, 'q_ask': 5.0, 'v': 16655.0, 'q_op': 173.0, 'c': 33.79, 'pct_change': 3.43}
# {'symbol': 'APPS', 'q_bid': 200.0, 'px_bid': 5.5, 'px_ask': 5.51, 'q_ask': 139.0, 'v': 43702.0, 'q_op': 116.0, 'c': 5.505, 'pct_change': -0.27}
# {'symbol': 'APTV', 'q_bid': 3.0, 'px_bid': 85.66, 'px_ask': 85.7, 'q_ask': 197.0, 'v': 39580.0, 'q_op': 369.0, 'c': 85.7, 'pct_change': 0.49}
# {'symbol': 'AQB', 'q_bid': 139.0, 'px_bid': 1.69, 'px_ask': 1.74, 'q_ask': 100.0, 'v': 19093.0, 'q_op': 41.0, 'c': 1.71, 'pct_change': 11.04}
# {'symbol': 'AQMS', 'q_bid': 100.0, 'px_bid': 4.03, 'px_ask': 4.24, 'q_ask': 100.0, 'v': 605.0, 'q_op': 6.0, 'c': 4.11, 'pct_change': -0.24}
# {'symbol': 'AQN', 'q_bid': 25011.0, 'px_bid': 5.46, 'px_ask': 5.47, 'q_ask': 10700.0, 'v': 48814.0, 'q_op': 73.0, 'c': 5.465, 'pct_change': -0.27}
# {'symbol': 'AQST', 'q_bid': 136.0, 'px_bid': 5.23, 'px_ask': 5.24, 'q_ask': 100.0, 'v': 15271.0, 'q_op': 186.0, 'c': 5.235, 'pct_change': -7.67}
# {'symbol': 'AR', 'q_bid': 138.0, 'px_bid': 32.3, 'px_ask': 32.33, 'q_ask': 200.0, 'v': 44426.0, 'q_op': 557.0, 'c': 32.315, 'pct_change': 1.94}
# {'symbol': 'ARCB', 'q_bid': 130.0, 'px_bid': 68.64, 'px_ask': 68.75, 'q_ask': 29.0, 'v': 7779.0, 'q_op': 142.0, 'c': 68.61, 'pct_change': -1.73}
# {'symbol': 'ARCC', 'q_bid': 1155.0, 'px_bid': 21.0, 'px_ask': 21.01, 'q_ask': 500.0, 'v': 56199.0, 'q_op': 208.0, 'c': 21.0, 'pct_change': -2.6}
# {'symbol': 'ARCO', 'q_bid': 171.0, 'px_bid': 6.92, 'px_ask': 6.93, 'q_ask': 481.0, 'v': 28696.0, 'q_op': 55.0, 'c': 6.925, 'pct_change': 3.2}
# {'symbol': 'ARCT', 'q_bid': 4.0, 'px_bid': 21.41, 'px_ask': 21.46, 'q_ask': 103.0, 'v': 18224.0, 'q_op': 182.0, 'c': 21.44, 'pct_change': 4.79}
# {'symbol': 'ARDT', 'q_bid': 6.0, 'px_bid': 12.99, 'px_ask': 13.01, 'q_ask': 40.0, 'v': 2781.0, 'q_op': 36.0, 'c': 12.94, 'pct_change': 0.94}
# {'symbol': 'ARDX', 'q_bid': 1000.0, 'px_bid': 6.24, 'px_ask': 6.25, 'q_ask': 905.0, 'v': 39665.0, 'q_op': 97.0, 'c': 6.255, 'pct_change': 0.72}
# {'symbol': 'ARE', 'q_bid': 116.0, 'px_bid': 86.02, 'px_ask': 86.07, 'q_ask': 1.0, 'v': 17829.0, 'q_op': 277.0, 'c': 86.04, 'pct_change': -0.17}
# {'symbol': 'ARES', 'q_bid': 2.0, 'px_bid': 181.33, 'px_ask': 181.49, 'q_ask': 35.0, 'v': 21770.0, 'q_op': 313.0, 'c': 181.565, 'pct_change': -0.78}
# {'symbol': 'ARGX', 'q_bid': 1.0, 'px_bid': 742.19, 'px_ask': 742.67, 'q_ask': 1.0, 'v': 8480.0, 'q_op': 290.0, 'c': 742.07, 'pct_change': 0.72}
# {'symbol': 'ARHS', 'q_bid': 25.0, 'px_bid': 10.99, 'px_ask': 11.01, 'q_ask': 100.0, 'v': 34684.0, 'q_op': 195.0, 'c': 11.01, 'pct_change': -0.45}
# {'symbol': 'ARI', 'q_bid': 156.0, 'px_bid': 10.43, 'px_ask': 10.44, 'q_ask': 1509.0, 'v': 15376.0, 'q_op': 38.0, 'c': 10.44, 'pct_change': -1.04}
# {'symbol': 'ARIS', 'q_bid': 2.0, 'px_bid': 24.08, 'px_ask': 24.09, 'q_ask': 4.0, 'v': 34804.0, 'q_op': 75.0, 'c': 24.08, 'pct_change': 0.21}
# {'symbol': 'ARKO', 'q_bid': 400.0, 'px_bid': 4.77, 'px_ask': 4.78, 'q_ask': 180.0, 'v': 12676.0, 'q_op': 30.0, 'c': 4.76, 'pct_change': -1.45}
# {'symbol': 'ARKQ', 'q_bid': 101.0, 'px_bid': 110.1, 'px_ask': 110.16, 'q_ask': 700.0, 'v': 23523.0, 'q_op': 106.0, 'c': 110.13, 'pct_change': 1.6}
# {'symbol': 'ARKR', 'q_bid': 100.0, 'px_bid': 7.17, 'px_ask': 7.38, 'q_ask': 100.0, 'v': 0.0, 'q_op': 0.0, 'c': 7.27, 'pct_change': -0.55}
# {'symbol': 'ARLO', 'q_bid': 19.0, 'px_bid': 18.44, 'px_ask': 18.45, 'q_ask': 14.0, 'v': 8489.0, 'q_op': 83.0, 'c': 18.46, 'pct_change': 2.16}
# {'symbol': 'ARM', 'q_bid': 2.0, 'px_bid': 145.03, 'px_ask': 145.12, 'q_ask': 206.0, 'v': 47511.0, 'q_op': 1214.0, 'c': 145.08, 'pct_change': 1.52}
# {'symbol': 'ARMK', 'q_bid': 10.0, 'px_bid': 37.52, 'px_ask': 37.56, 'q_ask': 20.0, 'v': 28519.0, 'q_op': 175.0, 'c': 37.52, 'pct_change': -0.24}
# {'symbol': 'AROC', 'q_bid': 106.0, 'px_bid': 24.4, 'px_ask': 24.44, 'q_ask': 26.0, 'v': 41340.0, 'q_op': 197.0, 'c': 24.41, 'pct_change': 1.29}
# {'symbol': 'AROW', 'q_bid': 3.0, 'px_bid': 29.14, 'px_ask': 29.42, 'q_ask': 100.0, 'v': 640.0, 'q_op': 15.0, 'c': 29.22, 'pct_change': -0.48}
# {'symbol': 'ARQQ', 'q_bid': 5.0, 'px_bid': 39.65, 'px_ask': 39.82, 'q_ask': 20.0, 'v': 27410.0, 'q_op': 302.0, 'c': 39.8, 'pct_change': -4.62}
# {'symbol': 'ARQT', 'q_bid': 30.0, 'px_bid': 17.61, 'px_ask': 17.64, 'q_ask': 110.0, 'v': 17986.0, 'q_op': 144.0, 'c': 17.63, 'pct_change': 1.44}
# {'symbol': 'ARR', 'q_bid': 506.0, 'px_bid': 14.17, 'px_ask': 14.18, 'q_ask': 943.0, 'v': 21556.0, 'q_op': 130.0, 'c': 14.175, 'pct_change': -2.84}
# {'symbol': 'ARRY', 'q_bid': 46.0, 'px_bid': 8.06, 'px_ask': 8.07, 'q_ask': 212.0, 'v': 14645.0, 'q_op': 268.0, 'c': 8.06, 'pct_change': -0.12}
# {'symbol': 'ARVN', 'q_bid': 100.0, 'px_bid': 7.55, 'px_ask': 7.56, 'q_ask': 100.0, 'v': 37687.0, 'q_op': 125.0, 'c': 7.55, 'pct_change': 0.4}
# {'symbol': 'ARW', 'q_bid': 1.0, 'px_bid': 121.77, 'px_ask': 121.9, 'q_ask': 74.0, 'v': 12386.0, 'q_op': 205.0, 'c': 121.82, 'pct_change': 0.08}
# {'symbol': 'ARWR', 'q_bid': 1.0, 'px_bid': 31.32, 'px_ask': 31.35, 'q_ask': 40.0, 'v': 34943.0, 'q_op': 332.0, 'c': 31.35, 'pct_change': 2.15}
# {'symbol': 'ARX', 'q_bid': 98.0, 'px_bid': 16.33, 'px_ask': 16.35, 'q_ask': 31.0, 'v': 14026.0, 'q_op': 56.0, 'c': 16.33, 'pct_change': 0.06}
# {'symbol': 'AS', 'q_bid': 25.0, 'px_bid': 35.51, 'px_ask': 35.52, 'q_ask': 300.0, 'v': 64515.0, 'q_op': 1118.0, 'c': 35.52, 'pct_change': -5.15}
# {'symbol': 'ASAN', 'q_bid': 100.0, 'px_bid': 14.43, 'px_ask': 14.44, 'q_ask': 28.0, 'v': 47062.0, 'q_op': 421.0, 'c': 14.44, 'pct_change': 1.69}
# {'symbol': 'ASB', 'q_bid': 5.0, 'px_bid': 25.74, 'px_ask': 25.77, 'q_ask': 200.0, 'v': 17712.0, 'q_op': 165.0, 'c': 25.74, 'pct_change': -2.02}
# {'symbol': 'ASC', 'q_bid': 23.0, 'px_bid': 12.59, 'px_ask': 12.6, 'q_ask': 100.0, 'v': 3465.0, 'q_op': 32.0, 'c': 12.63, 'pct_change': -0.63}
# {'symbol': 'ASG', 'q_bid': 1000.0, 'px_bid': 5.63, 'px_ask': 5.69, 'q_ask': 200.0, 'v': 1627.0, 'q_op': 3.0, 'c': 5.65, 'pct_change': 0.36}
# {'symbol': 'ASGN', 'q_bid': 40.0, 'px_bid': 50.37, 'px_ask': 50.42, 'q_ask': 100.0, 'v': 9371.0, 'q_op': 134.0, 'c': 50.31, 'pct_change': 2.17}
# {'symbol': 'ASH', 'q_bid': 3.0, 'px_bid': 50.06, 'px_ask': 50.09, 'q_ask': 5.0, 'v': 8305.0, 'q_op': 117.0, 'c': 50.03, 'pct_change': 0.58}
# {'symbol': 'ASLE', 'q_bid': 100.0, 'px_bid': 8.37, 'px_ask': 8.4, 'q_ask': 137.0, 'v': 2954.0, 'q_op': 30.0, 'c': 8.39, 'pct_change': 0.6}
# {'symbol': 'ASM', 'q_bid': 1740.0, 'px_bid': 4.74, 'px_ask': 4.75, 'q_ask': 1216.0, 'v': 17475.0, 'q_op': 287.0, 'c': 4.735, 'pct_change': 1.83}
# {'symbol': 'ASML', 'q_bid': 26.0, 'px_bid': 958.72, 'px_ask': 959.0, 'q_ask': 30.0, 'v': 32988.0, 'q_op': 1435.0, 'c': 959.15, 'pct_change': 2.9}
# {'symbol': 'ASND', 'q_bid': 1.0, 'px_bid': 195.86, 'px_ask': 196.12, 'q_ask': 84.0, 'v': 44364.0, 'q_op': 330.0, 'c': 196.105, 'pct_change': -0.8}
# {'symbol': 'ASPI', 'q_bid': 110.0, 'px_bid': 11.23, 'px_ask': 11.25, 'q_ask': 300.0, 'v': 21310.0, 'q_op': 603.0, 'c': 11.23, 'pct_change': 13.89}
# {'symbol': 'ASPN', 'q_bid': 300.0, 'px_bid': 7.23, 'px_ask': 7.25, 'q_ask': 100.0, 'v': 34938.0, 'q_op': 125.0, 'c': 7.27, 'pct_change': 6.29}
# {'symbol': 'ASRT', 'q_bid': 100.0, 'px_bid': 0.927, 'px_ask': 0.937, 'q_ask': 100.0, 'v': 1901.0, 'q_op': 13.0, 'c': 0.929, 'pct_change': 2.72}
# {'symbol': 'ASTE', 'q_bid': 8.0, 'px_bid': 48.06, 'px_ask': 48.14, 'q_ask': 93.0, 'v': 3935.0, 'q_op': 85.0, 'c': 48.08, 'pct_change': 0.56}
# {'symbol': 'ASTH', 'q_bid': 30.0, 'px_bid': 26.94, 'px_ask': 27.1, 'q_ask': 400.0, 'v': 10134.0, 'q_op': 114.0, 'c': 26.97, 'pct_change': -2.88}
# {'symbol': 'ASTL', 'q_bid': 554.0, 'px_bid': 4.25, 'px_ask': 4.26, 'q_ask': 349.0, 'v': 44839.0, 'q_op': 78.0, 'c': 4.255, 'pct_change': -3.08}
# {'symbol': 'ASTS', 'q_bid': 130.0, 'px_bid': 47.72, 'px_ask': 47.76, 'q_ask': 66.0, 'v': 30675.0, 'q_op': 2041.0, 'c': 47.74, 'pct_change': 5.85}
# {'symbol': 'ATAT', 'q_bid': 18.0, 'px_bid': 39.43, 'px_ask': 39.54, 'q_ask': 100.0, 'v': 11467.0, 'q_op': 72.0, 'c': 39.55, 'pct_change': -1.32}
# {'symbol': 'ATEC', 'q_bid': 10.0, 'px_bid': 15.5, 'px_ask': 15.53, 'q_ask': 104.0, 'v': 23743.0, 'q_op': 147.0, 'c': 15.55, 'pct_change': 0.06}
# {'symbol': 'ATEN', 'q_bid': 1.0, 'px_bid': 18.25, 'px_ask': 18.27, 'q_ask': 7.0, 'v': 8251.0, 'q_op': 72.0, 'c': 18.26, 'pct_change': 0.44}
# {'symbol': 'ATER', 'q_bid': 2.0, 'px_bid': 0.995, 'px_ask': 1.0, 'q_ask': 100.0, 'v': 74.0, 'q_op': 6.0, 'c': 0.992, 'pct_change': -0.29}
# {'symbol': 'ATGE', 'q_bid': 36.0, 'px_bid': 144.21, 'px_ask': 144.31, 'q_ask': 1.0, 'v': 9818.0, 'q_op': 183.0, 'c': 144.32, 'pct_change': 2.65}
# {'symbol': 'ATHE', 'q_bid': 100.0, 'px_bid': 4.37, 'px_ask': 4.5, 'q_ask': 100.0, 'v': 0.0, 'q_op': 0.0, 'c': 4.48, 'pct_change': 0.0}
# {'symbol': 'ATHM', 'q_bid': 8.0, 'px_bid': 29.33, 'px_ask': 29.35, 'q_ask': 106.0, 'v': 4423.0, 'q_op': 33.0, 'c': 29.34, 'pct_change': 0.72}
# {'symbol': 'ATI', 'q_bid': 2.0, 'px_bid': 79.5, 'px_ask': 79.56, 'q_ask': 9.0, 'v': 39493.0, 'q_op': 337.0, 'c': 79.54, 'pct_change': -1.47}
# {'symbol': 'ATKR', 'q_bid': 5.0, 'px_bid': 60.51, 'px_ask': 60.59, 'q_ask': 1.0, 'v': 13009.0, 'q_op': 178.0, 'c': 60.55, 'pct_change': 0.43}
# {'symbol': 'ATLC', 'q_bid': 2.0, 'px_bid': 69.35, 'px_ask': 69.94, 'q_ask': 100.0, 'v': 419.0, 'q_op': 30.0, 'c': 69.36, 'pct_change': -1.27}
# {'symbol': 'ATMU', 'q_bid': 51.0, 'px_bid': 46.03, 'px_ask': 46.09, 'q_ask': 27.0, 'v': 13175.0, 'q_op': 146.0, 'c': 46.05, 'pct_change': 0.15}
# {'symbol': 'ATO', 'q_bid': 100.0, 'px_bid': 163.41, 'px_ask': 163.5, 'q_ask': 44.0, 'v': 15457.0, 'q_op': 301.0, 'c': 163.43, 'pct_change': 0.31}
# {'symbol': 'ATR', 'q_bid': 5.0, 'px_bid': 133.19, 'px_ask': 133.42, 'q_ask': 4.0, 'v': 9875.0, 'q_op': 183.0, 'c': 133.29, 'pct_change': -0.86}
# {'symbol': 'ATRC', 'q_bid': 3.0, 'px_bid': 37.31, 'px_ask': 37.33, 'q_ask': 76.0, 'v': 13034.0, 'q_op': 125.0, 'c': 37.34, 'pct_change': 2.5}
# {'symbol': 'ATRO', 'q_bid': 13.0, 'px_bid': 42.14, 'px_ask': 42.19, 'q_ask': 3.0, 'v': 8034.0, 'q_op': 102.0, 'c': 42.22, 'pct_change': 1.49}
# {'symbol': 'ATS', 'q_bid': 3.0, 'px_bid': 27.75, 'px_ask': 27.79, 'q_ask': 4.0, 'v': 1311.0, 'q_op': 18.0, 'c': 27.74, 'pct_change': -0.43}
# {'symbol': 'ATUS', 'q_bid': 3856.0, 'px_bid': 2.69, 'px_ask': 2.7, 'q_ask': 1100.0, 'v': 36184.0, 'q_op': 42.0, 'c': 2.67, 'pct_change': -0.74}
# {'symbol': 'ATYR', 'q_bid': 4600.0, 'px_bid': 1.04, 'px_ask': 1.05, 'q_ask': 27295.0, 'v': 8949.0, 'q_op': 92.0, 'c': 1.045, 'pct_change': 5.33}
# {'symbol': 'AUB', 'q_bid': 20.0, 'px_bid': 35.75, 'px_ask': 35.8, 'q_ask': 5.0, 'v': 26729.0, 'q_op': 207.0, 'c': 35.79, 'pct_change': -2.05}
# {'symbol': 'AUPH', 'q_bid': 67.0, 'px_bid': 13.07, 'px_ask': 13.08, 'q_ask': 10.0, 'v': 32662.0, 'q_op': 138.0, 'c': 13.075, 'pct_change': 0.58}
# {'symbol': 'AUR', 'q_bid': 2414.0, 'px_bid': 6.05, 'px_ask': 6.06, 'q_ask': 1200.0, 'v': 48113.0, 'q_op': 178.0, 'c': 6.045, 'pct_change': -0.25}
# {'symbol': 'AURA', 'q_bid': 4.0, 'px_bid': 6.01, 'px_ask': 6.08, 'q_ask': 100.0, 'v': 6533.0, 'q_op': 33.0, 'c': 6.03, 'pct_change': -0.82}
# {'symbol': 'AUTL', 'q_bid': 7337.0, 'px_bid': 1.38, 'px_ask': 1.39, 'q_ask': 3600.0, 'v': 8767.0, 'q_op': 41.0, 'c': 1.385, 'pct_change': 3.36}
# {'symbol': 'AVA', 'q_bid': 100.0, 'px_bid': 36.71, 'px_ask': 36.73, 'q_ask': 200.0, 'v': 6529.0, 'q_op': 79.0, 'c': 36.66, 'pct_change': 0.83}
# {'symbol': 'AVAH', 'q_bid': 162.0, 'px_bid': 8.26, 'px_ask': 8.27, 'q_ask': 95.0, 'v': 23271.0, 'q_op': 71.0, 'c': 8.255, 'pct_change': 1.91}
# {'symbol': 'AVAV', 'q_bid': 200.0, 'px_bid': 285.93, 'px_ask': 286.11, 'q_ask': 2.0, 'v': 19986.0, 'q_op': 501.0, 'c': 285.93, 'pct_change': 2.65}
# {'symbol': 'AVB', 'q_bid': 2.0, 'px_bid': 193.6, 'px_ask': 193.67, 'q_ask': 1.0, 'v': 23415.0, 'q_op': 537.0, 'c': 193.6, 'pct_change': 0.33}
# {'symbol': 'AVDE', 'q_bid': 200.0, 'px_bid': 78.76, 'px_ask': 78.77, 'q_ask': 800.0, 'v': 3600.0, 'q_op': 20.0, 'c': 78.74, 'pct_change': 0.47}
# {'symbol': 'AVDL', 'q_bid': 116.0, 'px_bid': 16.07, 'px_ask': 16.08, 'q_ask': 6.0, 'v': 32217.0, 'q_op': 127.0, 'c': 16.09, 'pct_change': -0.68}
# {'symbol': 'AVDV', 'q_bid': 400.0, 'px_bid': 88.46, 'px_ask': 88.58, 'q_ask': 1.0, 'v': 8602.0, 'q_op': 46.0, 'c': 88.47, 'pct_change': 0.73}
# {'symbol': 'AVDX', 'q_bid': 60223.0, 'px_bid': 9.94, 'px_ask': 9.95, 'q_ask': 46332.0, 'v': 23974.0, 'q_op': 29.0, 'c': 9.945, 'pct_change': 0.05}
# {'symbol': 'AVEM', 'q_bid': 500.0, 'px_bid': 75.39, 'px_ask': 75.41, 'q_ask': 351.0, 'v': 24433.0, 'q_op': 61.0, 'c': 75.425, 'pct_change': 0.42}
# {'symbol': 'AVGO', 'q_bid': 64.0, 'px_bid': 341.38, 'px_ask': 341.44, 'q_ask': 51.0, 'v': 62553.0, 'q_op': 13462.0, 'c': 341.42, 'pct_change': -0.85}
# {'symbol': 'AVLV', 'q_bid': 100.0, 'px_bid': 72.49, 'px_ask': 72.51, 'q_ask': 230.0, 'v': 41592.0, 'q_op': 85.0, 'c': 72.45, 'pct_change': 0.11}
# {'symbol': 'AVNS', 'q_bid': 35.0, 'px_bid': 12.0, 'px_ask': 12.03, 'q_ask': 60.0, 'v': 15234.0, 'q_op': 69.0, 'c': 12.01, 'pct_change': 0.84}
# {'symbol': 'AVNT', 'q_bid': 2.0, 'px_bid': 34.87, 'px_ask': 34.9, 'q_ask': 2.0, 'v': 9721.0, 'q_op': 158.0, 'c': 34.88, 'pct_change': -0.74}
# {'symbol': 'AVNW', 'q_bid': 100.0, 'px_bid': 23.84, 'px_ask': 24.0, 'q_ask': 2.0, 'v': 984.0, 'q_op': 26.0, 'c': 23.98, 'pct_change': 0.93}
# {'symbol': 'AVPT', 'q_bid': 38.0, 'px_bid': 15.82, 'px_ask': 15.84, 'q_ask': 100.0, 'v': 18657.0, 'q_op': 101.0, 'c': 15.84, 'pct_change': 1.08}
# {'symbol': 'AVT', 'q_bid': 211.0, 'px_bid': 53.46, 'px_ask': 53.51, 'q_ask': 10.0, 'v': 6587.0, 'q_op': 131.0, 'c': 53.47, 'pct_change': 0.73}
# {'symbol': 'AVTR', 'q_bid': 1171.0, 'px_bid': 12.41, 'px_ask': 12.42, 'q_ask': 608.0, 'v': 47738.0, 'q_op': 290.0, 'c': 12.415, 'pct_change': -0.68}
# {'symbol': 'AVUV', 'q_bid': 100.0, 'px_bid': 100.61, 'px_ask': 100.64, 'q_ask': 220.0, 'v': 21672.0, 'q_op': 94.0, 'c': 100.63, 'pct_change': -0.08}
# {'symbol': 'AVXL', 'q_bid': 7.0, 'px_bid': 8.86, 'px_ask': 8.88, 'q_ask': 10.0, 'v': 16754.0, 'q_op': 80.0, 'c': 8.81, 'pct_change': 4.14}
# {'symbol': 'AVY', 'q_bid': 68.0, 'px_bid': 163.45, 'px_ask': 163.62, 'q_ask': 4.0, 'v': 7653.0, 'q_op': 184.0, 'c': 163.59, 'pct_change': -0.48}
# {'symbol': 'AWAY', 'q_bid': 300.0, 'px_bid': 22.97, 'px_ask': 23.07, 'q_ask': 100.0, 'v': 11456.0, 'q_op': 0.0, 'c': 23.05, 'pct_change': -0.12}
# {'symbol': 'AWF', 'q_bid': 1000.0, 'px_bid': 11.41, 'px_ask': 11.46, 'q_ask': 100.0, 'v': 2389.0, 'q_op': 6.0, 'c': 11.41, 'pct_change': 0.18}
# {'symbol': 'AWI', 'q_bid': 2.0, 'px_bid': 195.23, 'px_ask': 195.31, 'q_ask': 10.0, 'v': 2617.0, 'q_op': 96.0, 'c': 195.22, 'pct_change': -0.69}
# {'symbol': 'AWK', 'q_bid': 101.0, 'px_bid': 136.02, 'px_ask': 136.12, 'q_ask': 19.0, 'v': 27530.0, 'q_op': 357.0, 'c': 136.07, 'pct_change': 0.75}
# {'symbol': 'AWP', 'q_bid': 1210.0, 'px_bid': 3.96, 'px_ask': 3.98, 'q_ask': 200.0, 'v': 6117.0, 'q_op': 4.0, 'c': 3.975, 'pct_change': -0.62}
# {'symbol': 'AWR', 'q_bid': 1.0, 'px_bid': 72.42, 'px_ask': 72.47, 'q_ask': 8.0, 'v': 8411.0, 'q_op': 110.0, 'c': 72.43, 'pct_change': 0.75}
# {'symbol': 'AX', 'q_bid': 4.0, 'px_bid': 87.75, 'px_ask': 87.8, 'q_ask': 2.0, 'v': 4224.0, 'q_op': 122.0, 'c': 87.75, 'pct_change': -0.87}
# {'symbol': 'AXGN', 'q_bid': 155.0, 'px_bid': 17.59, 'px_ask': 17.61, 'q_ask': 1.0, 'v': 10300.0, 'q_op': 98.0, 'c': 17.61, 'pct_change': 2.38}
# {'symbol': 'AXL', 'q_bid': 126.0, 'px_bid': 6.06, 'px_ask': 6.07, 'q_ask': 300.0, 'v': 40534.0, 'q_op': 102.0, 'c': 6.075, 'pct_change': -1.86}
# {'symbol': 'AXON', 'q_bid': 8.0, 'px_bid': 775.63, 'px_ask': 776.17, 'q_ask': 6.0, 'v': 7052.0, 'q_op': 421.0, 'c': 775.71, 'pct_change': 0.15}
# {'symbol': 'AXP', 'q_bid': 190.0, 'px_bid': 342.34, 'px_ask': 342.52, 'q_ask': 8.0, 'v': 35884.0, 'q_op': 1478.0, 'c': 342.38, 'pct_change': 0.37}
# {'symbol': 'AXS', 'q_bid': 25.0, 'px_bid': 95.32, 'px_ask': 95.42, 'q_ask': 7.0, 'v': 10216.0, 'q_op': 195.0, 'c': 95.34, 'pct_change': -0.02}
# {'symbol': 'AXSM', 'q_bid': 1.0, 'px_bid': 116.88, 'px_ask': 116.95, 'q_ask': 1.0, 'v': 14917.0, 'q_op': 184.0, 'c': 116.9, 'pct_change': 0.82}
# {'symbol': 'AXTA', 'q_bid': 100.0, 'px_bid': 30.16, 'px_ask': 30.17, 'q_ask': 100.0, 'v': 62512.0, 'q_op': 255.0, 'c': 30.16, 'pct_change': -0.36}
# {'symbol': 'AYI', 'q_bid': 1.0, 'px_bid': 338.38, 'px_ask': 339.08, 'q_ask': 1.0, 'v': 4509.0, 'q_op': 134.0, 'c': 338.71, 'pct_change': 0.6}
# {'symbol': 'AYTU', 'q_bid': 100.0, 'px_bid': 2.5, 'px_ask': 2.56, 'q_ask': 400.0, 'v': 1893.0, 'q_op': 9.0, 'c': 2.53, 'pct_change': 3.69}
# {'symbol': 'AZO', 'q_bid': 9.0, 'px_bid': 4118.26, 'px_ask': 4118.87, 'q_ask': 1.0, 'v': 6226.0, 'q_op': 358.0, 'c': 4117.59, 'pct_change': -0.55}
# {'symbol': 'AZTA', 'q_bid': 2.0, 'px_bid': 31.69, 'px_ask': 31.75, 'q_ask': 8.0, 'v': 10802.0, 'q_op': 132.0, 'c': 31.635, 'pct_change': 1.75}
# {'symbol': 'AZZ', 'q_bid': 2.0, 'px_bid': 113.81, 'px_ask': 114.54, 'q_ask': 100.0, 'v': 1134.0, 'q_op': 49.0, 'c': 113.93, 'pct_change': 0.01}
# {'symbol': 'B', 'q_bid': 648.0, 'px_bid': 35.45, 'px_ask': 35.46, 'q_ask': 900.0, 'v': 6325.0, 'q_op': 2990.0, 'c': 35.46, 'pct_change': 7.49}
# {'symbol': 'BA', 'q_bid': 101.0, 'px_bid': 212.66, 'px_ask': 212.76, 'q_ask': 100.0, 'v': 62528.0, 'q_op': 2020.0, 'c': 212.65, 'pct_change': -1.39}
# {'symbol': 'BABA', 'q_bid': 88.0, 'px_bid': 163.94, 'px_ask': 163.95, 'q_ask': 117.0, 'v': 51201.0, 'q_op': 2855.0, 'c': 163.91, 'pct_change': 0.68}
# {'symbol': 'BAC', 'q_bid': 546.0, 'px_bid': 51.92, 'px_ask': 51.93, 'q_ask': 1350.0, 'v': 44280.0, 'q_op': 1179.0, 'c': 51.925, 'pct_change': -0.62}
# {'symbol': 'BAH', 'q_bid': 5.0, 'px_bid': 99.71, 'px_ask': 99.81, 'q_ask': 1.0, 'v': 43503.0, 'q_op': 478.0, 'c': 99.71, 'pct_change': -2.38}
# {'symbol': 'BAK', 'q_bid': 847.0, 'px_bid': 3.08, 'px_ask': 3.09, 'q_ask': 700.0, 'v': 19761.0, 'q_op': 16.0, 'c': 3.065, 'pct_change': -2.7}
# {'symbol': 'BALL', 'q_bid': 29.0, 'px_bid': 48.77, 'px_ask': 48.8, 'q_ask': 5.0, 'v': 36472.0, 'q_op': 342.0, 'c': 48.8, 'pct_change': 0.18}
# {'symbol': 'BAM', 'q_bid': 101.0, 'px_bid': 61.13, 'px_ask': 61.19, 'q_ask': 100.0, 'v': 42034.0, 'q_op': 230.0, 'c': 61.13, 'pct_change': 1.85}
# {'symbol': 'BANC', 'q_bid': 161.0, 'px_bid': 16.54, 'px_ask': 16.55, 'q_ask': 887.0, 'v': 38106.0, 'q_op': 156.0, 'c': 16.545, 'pct_change': -1.87}
# {'symbol': 'BANF', 'q_bid': 101.0, 'px_bid': 129.85, 'px_ask': 130.19, 'q_ask': 10.0, 'v': 3380.0, 'q_op': 197.0, 'c': 129.94, 'pct_change': -1.42}
# {'symbol': 'BANR', 'q_bid': 2.0, 'px_bid': 66.13, 'px_ask': 66.18, 'q_ask': 12.0, 'v': 1721.0, 'q_op': 72.0, 'c': 66.17, 'pct_change': -1.43}
# ...
# {'symbol': 'WKEY', 'q_bid': 100.0, 'px_bid': 6.36, 'px_ask': 6.69, 'q_ask': 100.0, 'v': 4191.0, 'q_op': 18.0, 'c': 6.635, 'pct_change': 2.71}
# {'symbol': 'WKHS', 'q_bid': 1228.0, 'px_bid': 1.14, 'px_ask': 1.17, 'q_ask': 700.0, 'v': 8806.0, 'q_op': 10.0, 'c': 1.135, 'pct_change': 1.34}
# {'symbol': 'WLDN', 'q_bid': 6.0, 'px_bid': 106.27, 'px_ask': 106.62, 'q_ask': 15.0, 'v': 4877.0, 'q_op': 136.0, 'c': 106.53, 'pct_change': 3.1}
# {'symbol': 'WLFC', 'q_bid': 7.0, 'px_bid': 147.68, 'px_ask': 148.32, 'q_ask': 14.0, 'v': 2330.0, 'q_op': 208.0, 'c': 147.95, 'pct_change': 1.47}
# {'symbol': 'WLK', 'q_bid': 8.0, 'px_bid': 81.96, 'px_ask': 82.07, 'q_ask': 6.0, 'v': 25469.0, 'q_op': 328.0, 'c': 82.0, 'pct_change': -1.29}
# {'symbol': 'WLY', 'q_bid': 6.0, 'px_bid': 40.03, 'px_ask': 40.1, 'q_ask': 12.0, 'v': 3074.0, 'q_op': 68.0, 'c': 40.07, 'pct_change': -0.62}
# {'symbol': 'WM', 'q_bid': 108.0, 'px_bid': 216.66, 'px_ask': 216.73, 'q_ask': 5.0, 'v': 36602.0, 'q_op': 586.0, 'c': 216.67, 'pct_change': 0.12}
# {'symbol': 'WMB', 'q_bid': 131.0, 'px_bid': 60.56, 'px_ask': 60.57, 'q_ask': 237.0, 'v': 52948.0, 'q_op': 723.0, 'c': 60.59, 'pct_change': 0.8}
# {'symbol': 'WMG', 'q_bid': 5.0, 'px_bid': 33.15, 'px_ask': 33.16, 'q_ask': 11.0, 'v': 17518.0, 'q_op': 134.0, 'c': 33.16, 'pct_change': -1.13}
# {'symbol': 'WMK', 'q_bid': 4.0, 'px_bid': 69.25, 'px_ask': 69.32, 'q_ask': 1.0, 'v': 4995.0, 'q_op': 95.0, 'c': 69.35, 'pct_change': -2.21}
# {'symbol': 'WMS', 'q_bid': 1.0, 'px_bid': 144.04, 'px_ask': 144.32, 'q_ask': 18.0, 'v': 10547.0, 'q_op': 255.0, 'c': 143.79, 'pct_change': 0.43}
# {'symbol': 'WMT', 'q_bid': 200.0, 'px_bid': 102.7, 'px_ask': 102.72, 'q_ask': 225.0, 'v': 46924.0, 'q_op': 1851.0, 'c': 102.71, 'pct_change': 0.37}
# {'symbol': 'WNC', 'q_bid': 25.0, 'px_bid': 10.78, 'px_ask': 10.82, 'q_ask': 25.0, 'v': 5242.0, 'q_op': 49.0, 'c': 10.8, 'pct_change': -0.74}
# {'symbol': 'WOOF', 'q_bid': 326.0, 'px_bid': 3.53, 'px_ask': 3.54, 'q_ask': 512.0, 'v': 58913.0, 'q_op': 90.0, 'c': 3.535, 'pct_change': 0.43}
# {'symbol': 'WOR', 'q_bid': 1.0, 'px_bid': 61.3, 'px_ask': 61.36, 'q_ask': 8.0, 'v': 4636.0, 'q_op': 85.0, 'c': 61.31, 'pct_change': 0.41}
# {'symbol': 'WOW', 'q_bid': 3030.0, 'px_bid': 5.19, 'px_ask': 5.2, 'q_ask': 2600.0, 'v': 16973.0, 'q_op': 21.0, 'c': 5.195, 'pct_change': 0.87}
# {'symbol': 'WPC', 'q_bid': 13.0, 'px_bid': 67.25, 'px_ask': 67.27, 'q_ask': 21.0, 'v': 9999.0, 'q_op': 185.0, 'c': 67.23, 'pct_change': 0.09}
# {'symbol': 'WPM', 'q_bid': 71.0, 'px_bid': 107.8, 'px_ask': 107.84, 'q_ask': 100.0, 'v': 39745.0, 'q_op': 1188.0, 'c': 107.78, 'pct_change': 0.12}
# {'symbol': 'WPP', 'q_bid': 4.0, 'px_bid': 24.3, 'px_ask': 24.33, 'q_ask': 180.0, 'v': 10950.0, 'q_op': 72.0, 'c': 24.3, 'pct_change': 1.08}
# {'symbol': 'WRAP', 'q_bid': 200.0, 'px_bid': 2.5, 'px_ask': 2.62, 'q_ask': 121.0, 'v': 6876.0, 'q_op': 29.0, 'c': 2.58, 'pct_change': -0.39}
# {'symbol': 'WRB', 'q_bid': 69.0, 'px_bid': 73.44, 'px_ask': 73.46, 'q_ask': 3.0, 'v': 42851.0, 'q_op': 555.0, 'c': 73.43, 'pct_change': 0.18}
# {'symbol': 'WRBY', 'q_bid': 6.0, 'px_bid': 28.19, 'px_ask': 28.21, 'q_ask': 8.0, 'v': 19303.0, 'q_op': 162.0, 'c': 28.2, 'pct_change': -0.98}
# {'symbol': 'WRD', 'q_bid': 200.0, 'px_bid': 11.64, 'px_ask': 11.65, 'q_ask': 310.0, 'v': 832.0, 'q_op': 770.0, 'c': 11.645, 'pct_change': 1.0}
# {'symbol': 'WRLD', 'q_bid': 100.0, 'px_bid': 174.3, 'px_ask': 175.27, 'q_ask': 3.0, 'v': 2905.0, 'q_op': 122.0, 'c': 175.27, 'pct_change': 1.82}
# {'symbol': 'WS', 'q_bid': 100.0, 'px_bid': 33.43, 'px_ask': 33.56, 'q_ask': 101.0, 'v': 5151.0, 'q_op': 80.0, 'c': 33.58, 'pct_change': 0.03}
# {'symbol': 'WSBC', 'q_bid': 10.0, 'px_bid': 31.89, 'px_ask': 31.92, 'q_ask': 12.0, 'v': 17301.0, 'q_op': 166.0, 'c': 31.89, 'pct_change': -1.18}
# {'symbol': 'WSC', 'q_bid': 45.0, 'px_bid': 22.33, 'px_ask': 22.35, 'q_ask': 100.0, 'v': 27738.0, 'q_op': 202.0, 'c': 22.33, 'pct_change': -1.06}
# {'symbol': 'WSFS', 'q_bid': 42.0, 'px_bid': 54.86, 'px_ask': 54.88, 'q_ask': 1.0, 'v': 6046.0, 'q_op': 148.0, 'c': 54.86, 'pct_change': -1.03}
# {'symbol': 'WSM', 'q_bid': 10.0, 'px_bid': 196.18, 'px_ask': 196.21, 'q_ask': 50.0, 'v': 23326.0, 'q_op': 419.0, 'c': 196.2, 'pct_change': -1.03}
# {'symbol': 'WSO', 'q_bid': 1.0, 'px_bid': 389.21, 'px_ask': 390.39, 'q_ask': 1.0, 'v': 39609.0, 'q_op': 404.0, 'c': 391.41, 'pct_change': 0.4}
# {'symbol': 'WSR', 'q_bid': 45.0, 'px_bid': 12.82, 'px_ask': 12.84, 'q_ask': 100.0, 'v': 3209.0, 'q_op': 27.0, 'c': 12.83, 'pct_change': 0.79}
# {'symbol': 'WST', 'q_bid': 9.0, 'px_bid': 252.04, 'px_ask': 252.2, 'q_ask': 2.0, 'v': 7212.0, 'q_op': 237.0, 'c': 252.13, 'pct_change': -1.07}
# {'symbol': 'WTBA', 'q_bid': 100.0, 'px_bid': 20.42, 'px_ask': 20.56, 'q_ask': 20.0, 'v': 760.0, 'q_op': 24.0, 'c': 20.51, 'pct_change': 0.34}
# {'symbol': 'WTFC', 'q_bid': 1.0, 'px_bid': 133.43, 'px_ask': 133.53, 'q_ask': 1.0, 'v': 24519.0, 'q_op': 280.0, 'c': 133.5, 'pct_change': -1.17}
# {'symbol': 'WTM', 'q_bid': 5.0, 'px_bid': 1750.02, 'px_ask': 1758.85, 'q_ask': 1.0, 'v': 777.0, 'q_op': 104.0, 'c': 1758.11, 'pct_change': -0.66}
# {'symbol': 'WTRG', 'q_bid': 1.0, 'px_bid': 37.24, 'px_ask': 37.24, 'q_ask': 7.0, 'v': 19392.0, 'q_op': 188.0, 'c': 37.22, 'pct_change': 0.54}
# {'symbol': 'WTS', 'q_bid': 5.0, 'px_bid': 280.28, 'px_ask': 280.54, 'q_ask': 5.0, 'v': 2199.0, 'q_op': 106.0, 'c': 280.55, 'pct_change': -0.14}
# {'symbol': 'WTTR', 'q_bid': 501.0, 'px_bid': 10.15, 'px_ask': 10.19, 'q_ask': 100.0, 'v': 23935.0, 'q_op': 102.0, 'c': 10.15, 'pct_change': 1.7}
# {'symbol': 'WTW', 'q_bid': 1.0, 'px_bid': 336.64, 'px_ask': 336.93, 'q_ask': 7.0, 'v': 7701.0, 'q_op': 218.0, 'c': 336.81, 'pct_change': 0.03}
# {'symbol': 'WU', 'q_bid': 600.0, 'px_bid': 8.11, 'px_ask': 8.12, 'q_ask': 3100.0, 'v': 11075.0, 'q_op': 134.0, 'c': 8.11, 'pct_change': -0.37}
# {'symbol': 'WULF', 'q_bid': 572.0, 'px_bid': 11.47, 'px_ask': 11.48, 'q_ask': 200.0, 'v': 28210.0, 'q_op': 1269.0, 'c': 11.46, 'pct_change': 4.37}
# {'symbol': 'WVE', 'q_bid': 10.0, 'px_bid': 6.81, 'px_ask': 6.82, 'q_ask': 390.0, 'v': 33242.0, 'q_op': 112.0, 'c': 6.865, 'pct_change': -0.36}
# {'symbol': 'WW', 'q_bid': 148.0, 'px_bid': 29.61, 'px_ask': 29.92, 'q_ask': 100.0, 'v': 2398.0, 'q_op': 21.0, 'c': 29.79, 'pct_change': 0.07}
# {'symbol': 'WWD', 'q_bid': 19.0, 'px_bid': 239.88, 'px_ask': 239.85, 'q_ask': 1.0, 'v': 10228.0, 'q_op': 286.0, 'c': 239.88, 'pct_change': 0.74}
# {'symbol': 'WWR', 'q_bid': 100.0, 'px_bid': 0.833, 'px_ask': 0.848, 'q_ask': 500.0, 'v': 19461.0, 'q_op': 23.0, 'c': 0.832, 'pct_change': 12.29}
# {'symbol': 'WWW', 'q_bid': 100.0, 'px_bid': 29.1, 'px_ask': 29.12, 'q_ask': 37.0, 'v': 39725.0, 'q_op': 245.0, 'c': 29.09, 'pct_change': -3.32}
# {'symbol': 'WY', 'q_bid': 302.0, 'px_bid': 24.32, 'px_ask': 24.33, 'q_ask': 200.0, 'v': 7293.0, 'q_op': 206.0, 'c': 24.32, 'pct_change': 0.91}
# {'symbol': 'WYFI', 'q_bid': 100.0, 'px_bid': 27.34, 'px_ask': 27.55, 'q_ask': 100.0, 'v': 27976.0, 'q_op': 134.0, 'c': 27.34, 'pct_change': 3.95}
# {'symbol': 'WYNN', 'q_bid': 1.0, 'px_bid': 126.21, 'px_ask': 126.27, 'q_ask': 1.0, 'v': 43918.0, 'q_op': 558.0, 'c': 126.22, 'pct_change': -2.55}
# {'symbol': 'XBIT', 'q_bid': 100.0, 'px_bid': 2.66, 'px_ask': 2.73, 'q_ask': 100.0, 'v': 224.0, 'q_op': 2.0, 'c': 2.68, 'pct_change': -1.47}
# {'symbol': 'XEL', 'q_bid': 149.0, 'px_bid': 72.41, 'px_ask': 72.44, 'q_ask': 11.0, 'v': 29548.0, 'q_op': 616.0, 'c': 72.43, 'pct_change': 0.44}
# {'symbol': 'XENE', 'q_bid': 25.0, 'px_bid': 37.57, 'px_ask': 37.63, 'q_ask': 3.0, 'v': 9234.0, 'q_op': 106.0, 'c': 37.61, 'pct_change': 1.79}
# {'symbol': 'XERS', 'q_bid': 24.0, 'px_bid': 7.91, 'px_ask': 7.92, 'q_ask': 200.0, 'v': 16345.0, 'q_op': 88.0, 'c': 7.9, 'pct_change': 2.33}
# {'symbol': 'XFLT', 'q_bid': 200.0, 'px_bid': 5.34, 'px_ask': 5.35, 'q_ask': 500.0, 'v': 4079.0, 'q_op': 3.0, 'c': 5.345, 'pct_change': 0.09}
# {'symbol': 'XHLF', 'q_bid': 18800.0, 'px_bid': 50.38, 'px_ask': 50.39, 'q_ask': 13200.0, 'v': 277956.0, 'q_op': 0.0, 'c': 50.385, 'pct_change': 0.03}
# {'symbol': 'XHR', 'q_bid': 154.0, 'px_bid': 14.44, 'px_ask': 14.47, 'q_ask': 47.0, 'v': 6645.0, 'q_op': 55.0, 'c': 14.44, 'pct_change': -2.3}
# {'symbol': 'XIFR', 'q_bid': 100.0, 'px_bid': 9.76, 'px_ask': 9.77, 'q_ask': 104.0, 'v': 22536.0, 'q_op': 89.0, 'c': 9.755, 'pct_change': -1.27}
# {'symbol': 'XMHQ', 'q_bid': 40.0, 'px_bid': 105.66, 'px_ask': 105.74, 'q_ask': 100.0, 'v': 6099.0, 'q_op': 34.0, 'c': 105.62, 'pct_change': -0.19}
# {'symbol': 'XMTR', 'q_bid': 100.0, 'px_bid': 54.51, 'px_ask': 54.59, 'q_ask': 21.0, 'v': 10629.0, 'q_op': 141.0, 'c': 54.51, 'pct_change': 1.3}
# {'symbol': 'XNCR', 'q_bid': 100.0, 'px_bid': 10.57, 'px_ask': 10.58, 'q_ask': 103.0, 'v': 39927.0, 'q_op': 176.0, 'c': 10.57, 'pct_change': 2.72}
# {'symbol': 'XNET', 'q_bid': 104.0, 'px_bid': 7.8, 'px_ask': 7.83, 'q_ask': 1.0, 'v': 18774.0, 'q_op': 51.0, 'c': 7.81, 'pct_change': 0.9}
# {'symbol': 'XOM', 'q_bid': 5.0, 'px_bid': 112.02, 'px_ask': 112.03, 'q_ask': 1.0, 'v': 30375.0, 'q_op': 1777.0, 'c': 112.015, 'pct_change': -0.71}
# {'symbol': 'XOMA', 'q_bid': 4.0, 'px_bid': 36.51, 'px_ask': 37.21, 'q_ask': 100.0, 'v': 4678.0, 'q_op': 34.0, 'c': 36.58, 'pct_change': -0.33}
# {'symbol': 'XOS', 'q_bid': 100.0, 'px_bid': 2.81, 'px_ask': 2.97, 'q_ask': 100.0, 'v': 718.0, 'q_op': 5.0, 'c': 2.84, 'pct_change': 0.0}
# {'symbol': 'XP', 'q_bid': 500.0, 'px_bid': 19.51, 'px_ask': 19.52, 'q_ask': 605.0, 'v': 8619.0, 'q_op': 481.0, 'c': 19.52, 'pct_change': -1.21}
# {'symbol': 'XPEL', 'q_bid': 139.0, 'px_bid': 32.66, 'px_ask': 32.73, 'q_ask': 1.0, 'v': 11379.0, 'q_op': 131.0, 'c': 32.68, 'pct_change': -1.33}
# {'symbol': 'XPEV', 'q_bid': 423.0, 'px_bid': 21.32, 'px_ask': 21.33, 'q_ask': 146.0, 'v': 40098.0, 'q_op': 330.0, 'c': 21.325, 'pct_change': -1.55}
# {'symbol': 'XPO', 'q_bid': 22.0, 'px_bid': 131.1, 'px_ask': 131.28, 'q_ask': 5.0, 'v': 18698.0, 'q_op': 317.0, 'c': 131.22, 'pct_change': 0.21}
# {'symbol': 'XPOF', 'q_bid': 25.0, 'px_bid': 8.02, 'px_ask': 8.04, 'q_ask': 38.0, 'v': 21430.0, 'q_op': 81.0, 'c': 8.03, 'pct_change': 1.39}
# {'symbol': 'XPRO', 'q_bid': 20.0, 'px_bid': 11.99, 'px_ask': 12.02, 'q_ask': 120.0, 'v': 9859.0, 'q_op': 70.0, 'c': 11.99, 'pct_change': -0.08}
# {'symbol': 'XRAY', 'q_bid': 458.0, 'px_bid': 13.29, 'px_ask': 13.3, 'q_ask': 100.0, 'v': 26562.0, 'q_op': 160.0, 'c': 13.29, 'pct_change': 0.99}
# {'symbol': 'XRX', 'q_bid': 653.0, 'px_bid': 4.12, 'px_ask': 4.13, 'q_ask': 317.0, 'v': 32235.0, 'q_op': 147.0, 'c': 4.125, 'pct_change': 0.61}
# {'symbol': 'XTIA', 'q_bid': 100.0, 'px_bid': 1.58, 'px_ask': 1.59, 'q_ask': 300.0, 'v': 9377.0, 'q_op': 19.0, 'c': 1.58, 'pct_change': -1.25}
# {'symbol': 'XWEL', 'q_bid': 7.0, 'px_bid': 1.09, 'px_ask': 1.16, 'q_ask': 100.0, 'v': 0.0, 'q_op': 0.0, 'c': 1.11, 'pct_change': -0.89}
# {'symbol': 'XYF', 'q_bid': 17.0, 'px_bid': 14.62, 'px_ask': 14.78, 'q_ask': 100.0, 'v': 10402.0, 'q_op': 37.0, 'c': 14.63, 'pct_change': -3.11}
# {'symbol': 'XYL', 'q_bid': 2.0, 'px_bid': 143.53, 'px_ask': 143.58, 'q_ask': 100.0, 'v': 25303.0, 'q_op': 340.0, 'c': 143.56, 'pct_change': 0.48}
# {'symbol': 'XYLD', 'q_bid': 10026.0, 'px_bid': 39.16, 'px_ask': 39.17, 'q_ask': 13600.0, 'v': 17082.0, 'q_op': 21.0, 'c': 39.165, 'pct_change': 0.2}
# {'symbol': 'XYZ', 'q_bid': 10.0, 'px_bid': 77.03, 'px_ask': 77.08, 'q_ask': 1.0, 'v': 16995.0, 'q_op': 2018.0, 'c': 77.06, 'pct_change': 0.04}
# {'symbol': 'YALA', 'q_bid': 100.0, 'px_bid': 7.57, 'px_ask': 7.62, 'q_ask': 10.0, 'v': 9464.0, 'q_op': 35.0, 'c': 7.62, 'pct_change': 1.74}
# {'symbol': 'YELP', 'q_bid': 63.0, 'px_bid': 31.88, 'px_ask': 31.9, 'q_ask': 22.0, 'v': 9035.0, 'q_op': 92.0, 'c': 31.89, 'pct_change': 0.19}
# {'symbol': 'YETI', 'q_bid': 100.0, 'px_bid': 35.21, 'px_ask': 35.24, 'q_ask': 2.0, 'v': 22593.0, 'q_op': 221.0, 'c': 35.23, 'pct_change': 1.85}
# {'symbol': 'YEXT', 'q_bid': 254.0, 'px_bid': 8.85, 'px_ask': 8.86, 'q_ask': 579.0, 'v': 9750.0, 'q_op': 63.0, 'c': 8.85, 'pct_change': 0.45}
# {'symbol': 'YI', 'q_bid': 100.0, 'px_bid': 4.96, 'px_ask': 5.05, 'q_ask': 200.0, 'v': 739.0, 'q_op': 5.0, 'c': 5.11, 'pct_change': -2.11}
# {'symbol': 'YJ', 'q_bid': 100.0, 'px_bid': 1.83, 'px_ask': 1.98, 'q_ask': 100.0, 'v': 0.0, 'q_op': 0.0, 'c': 1.88, 'pct_change': 1.62}
# {'symbol': 'YMM', 'q_bid': 300.0, 'px_bid': 13.54, 'px_ask': 13.55, 'q_ask': 1973.0, 'v': 44771.0, 'q_op': 132.0, 'c': 13.545, 'pct_change': -0.33}
# {'symbol': 'YORW', 'q_bid': 2.0, 'px_bid': 30.79, 'px_ask': 30.85, 'q_ask': 5.0, 'v': 1650.0, 'q_op': 60.0, 'c': 30.8, 'pct_change': 0.39}
# {'symbol': 'YOU', 'q_bid': 49.0, 'px_bid': 38.24, 'px_ask': 38.29, 'q_ask': 18.0, 'v': 33305.0, 'q_op': 255.0, 'c': 38.26, 'pct_change': 0.82}
# {'symbol': 'YUM', 'q_bid': 2.0, 'px_bid': 149.12, 'px_ask': 149.26, 'q_ask': 8.0, 'v': 5202.0, 'q_op': 658.0, 'c': 149.2, 'pct_change': 2.43}
# {'symbol': 'YUMC', 'q_bid': 18.0, 'px_bid': 43.12, 'px_ask': 43.14, 'q_ask': 2.0, 'v': 49491.0, 'q_op': 219.0, 'c': 43.13, 'pct_change': -1.44}
# {'symbol': 'Z', 'q_bid': 20.0, 'px_bid': 81.86, 'px_ask': 81.92, 'q_ask': 1.0, 'v': 22641.0, 'q_op': 1052.0, 'c': 81.92, 'pct_change': -5.56}
# {'symbol': 'ZBH', 'q_bid': 100.0, 'px_bid': 101.65, 'px_ask': 101.67, 'q_ask': 95.0, 'v': 30081.0, 'q_op': 337.0, 'c': 101.64, 'pct_change': 1.55}
# {'symbol': 'ZBRA', 'q_bid': 10.0, 'px_bid': 316.39, 'px_ask': 316.49, 'q_ask': 1.0, 'v': 21087.0, 'q_op': 358.0, 'c': 316.485, 'pct_change': -0.65}
# {'symbol': 'ZD', 'q_bid': 5.0, 'px_bid': 37.88, 'px_ask': 37.93, 'q_ask': 1.0, 'v': 17398.0, 'q_op': 194.0, 'c': 37.89, 'pct_change': -1.07}
# {'symbol': 'ZETA', 'q_bid': 205.0, 'px_bid': 21.99, 'px_ask': 22.01, 'q_ask': 221.0, 'v': 47031.0, 'q_op': 617.0, 'c': 22.01, 'pct_change': 2.42}
# {'symbol': 'ZEUS', 'q_bid': 14.0, 'px_bid': 31.93, 'px_ask': 32.08, 'q_ask': 9.0, 'v': 1341.0, 'q_op': 36.0, 'c': 32.0, 'pct_change': -0.9}
# {'symbol': 'ZG', 'q_bid': 5.0, 'px_bid': 78.79, 'px_ask': 78.87, 'q_ask': 1.0, 'v': 29911.0, 'q_op': 459.0, 'c': 78.825, 'pct_change': -5.81}
# {'symbol': 'ZGN', 'q_bid': 569.0, 'px_bid': 9.48, 'px_ask': 9.49, 'q_ask': 100.0, 'v': 20476.0, 'q_op': 59.0, 'c': 9.49, 'pct_change': -0.11}
# {'symbol': 'ZIM', 'q_bid': 414.0, 'px_bid': 14.51, 'px_ask': 14.52, 'q_ask': 12.0, 'v': 13195.0, 'q_op': 126.0, 'c': 14.51, 'pct_change': 0.97}
# {'symbol': 'ZIMV', 'q_bid': 1161.0, 'px_bid': 18.9, 'px_ask': 18.91, 'q_ask': 699.0, 'v': 18696.0, 'q_op': 12.0, 'c': 18.9, 'pct_change': -0.05}
# {'symbol': 'ZION', 'q_bid': 100.0, 'px_bid': 56.94, 'px_ask': 56.97, 'q_ask': 8.0, 'v': 31045.0, 'q_op': 547.0, 'c': 56.96, 'pct_change': -2.96}
# {'symbol': 'ZIP', 'q_bid': 100.0, 'px_bid': 5.07, 'px_ask': 5.08, 'q_ask': 134.0, 'v': 20686.0, 'q_op': 65.0, 'c': 5.085, 'pct_change': 0.49}
# {'symbol': 'ZK', 'q_bid': 86.0, 'px_bid': 29.53, 'px_ask': 29.56, 'q_ask': 100.0, 'v': 13944.0, 'q_op': 72.0, 'c': 29.57, 'pct_change': -1.24}
# {'symbol': 'ZKH', 'q_bid': 200.0, 'px_bid': 2.94, 'px_ask': 3.0, 'q_ask': 200.0, 'v': 186.0, 'q_op': 3.0, 'c': 2.96, 'pct_change': 2.07}
# {'symbol': 'ZM', 'q_bid': 125.0, 'px_bid': 84.45, 'px_ask': 84.52, 'q_ask': 100.0, 'v': 20337.0, 'q_op': 661.0, 'c': 84.5, 'pct_change': 0.4}
# {'symbol': 'ZROZ', 'q_bid': 300.0, 'px_bid': 67.04, 'px_ask': 67.17, 'q_ask': 201.0, 'v': 8119.0, 'q_op': 33.0, 'c': 67.19, 'pct_change': -0.36}
# {'symbol': 'ZS', 'q_bid': 6.0, 'px_bid': 292.92, 'px_ask': 293.28, 'q_ask': 3.0, 'v': 19795.0, 'q_op': 556.0, 'c': 292.98, 'pct_change': -0.44}
# {'symbol': 'ZTO', 'q_bid': 424.0, 'px_bid': 18.78, 'px_ask': 18.79, 'q_ask': 50.0, 'v': 33513.0, 'q_op': 69.0, 'c': 18.78, 'pct_change': 0.97}
# {'symbol': 'ZTS', 'q_bid': 14.0, 'px_bid': 145.13, 'px_ask': 145.21, 'q_ask': 1.0, 'v': 35896.0, 'q_op': 528.0, 'c': 145.17, 'pct_change': -0.49}
# {'symbol': 'ZVRA', 'q_bid': 145.0, 'px_bid': 7.94, 'px_ask': 7.95, 'q_ask': 14.0, 'v': 23777.0, 'q_op': 90.0, 'c': 7.95, 'pct_change': 3.65}
# {'symbol': 'ZWS', 'q_bid': 21.0, 'px_bid': 47.0, 'px_ask': 47.02, 'q_ask': 1.0, 'v': 13904.0, 'q_op': 193.0, 'c': 47.01, 'pct_change': 0.23}
# {'symbol': 'ZYME', 'q_bid': 34.0, 'px_bid': 16.61, 'px_ask': 16.62, 'q_ask': 100.0, 'v': 20255.0, 'q_op': 120.0, 'c': 16.63, 'pct_change': 2.34}

# %%
ts_price = None
for item in data:
    if item.get('symbol') == 'D':
        ts_price = item.get('c')
        break

if ts_price is not None:
    print(f"The latest price for TS is: {ts_price}")
else:
    print("TS not found in the data.")
# Out:
# TS not found in the data.

# %%
new_X = np.array([62.15, 96.96, 6757]).reshape(1, -1)

# %%
y_pred_new = modelo.predict(new_X)
print(f"Predicted TS value: {y_pred_new[0]:.4f}")
# Out:
# Predicted TS value: 34.2007
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
