# %% [markdown]
# <a href="https://colab.research.google.com/github/Mart1n2015/MartinCerioli/blob/main/TS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from typing_extensions import Required
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import pandas as pd
import requests

# %%
url_dataset = "https://raw.githubusercontent.com/Mart1n2015/MartinCerioli/2ecf72ab3b51ec7a33bdcdcad861580635352f5e/Datos%20hist%C3%B3ricos%20de%20Tenaris%20ADR%20(TS).csv"

# %%
df = pd.read_csv(url_dataset,sep = ";")

# %%
df
# Out:
#           Fecha PETROLEO     TS   DÓLAR      S&P
# 0     30/6/2025    65,16  37,45  96,493  6204,95
# 1     27/6/2025    65,52  36,91  97,031  6173,07
# 2     26/6/2025    65,24  36,49  96,762  6141,02
# 3     25/6/2025    64,92  35,51  97,273  6092,16
# 4     24/6/2025    64,37   35,7   97,45  6092,18
# ...         ...      ...    ...     ...      ...
# 1104   4/2/2021    56,07  16,41   91,52   3871,7
# 1105   3/2/2021    55,54  16,26  91,148   3830,2
# 1106   2/2/2021    54,62  16,05  91,189   3826,3
# 1107   1/2/2021    53,42  15,79  90,975   3773,9
# 1108  29/1/2021    52,08  15,46  90,569   3714,2
#
# [1109 rows x 5 columns]

# %%
df['PETROLEO'] = df['PETROLEO'].str.replace(',', '.').astype(float)
df['TS'] = df['TS'].str.replace(',', '.').astype(float)
df['DÓLAR'] = df['DÓLAR'].str.replace(',', '.').astype(float)
df['S&P'] = df['S&P'].str.replace(',', '.').astype(float)

# %%
x1 = df ['PETROLEO']
x2 = df ['DÓLAR']
x3 = df ['S&P']
y = df ['TS']

# %%
modelo = LinearRegression()
X = pd.concat([x1, x2, x3], axis=1)
modelo.fit(X, y)
# Out:
# LinearRegression()

# %%
print(f"Coeficiente (pendiente): {modelo.coef_[0]:.4f}")
print(f"Intercepto: {modelo.intercept_:.4f}")
print(f"R² (bondad del ajuste): {modelo.score(X, y):.4f}")
# Out:
# Coeficiente (pendiente): 0.0308
# Intercepto: -52.2464
# R² (bondad del ajuste): 0.6553

# %%
url = "https://data912.com/live/usa_adrs"
param = {"symbol": "TS"}
response = requests.get(url, params=param)
data = response.json()

# %%
response = requests.get(url, params=param)
if response.status_code == 200:
    data = response.json()
    print(data)
else:
    print(f"Error {response.status_code}: {response.text}")
# Out:
# [{'symbol': 'AEM', 'q_bid': 5.0, 'px_bid': 162.42, 'px_ask': 162.46, 'q_ask': 100.0, 'v': 51739.0, 'q_op': 1528.0, 'c': 162.44, 'pct_change': 0.78}, {'symbol': 'AER', 'q_bid': 197.0, 'px_bid': 122.21, 'px_ask': 122.24, 'q_ask': 200.0, 'v': 26894.0, 'q_op': 234.0, 'c': 122.23, 'pct_change': -0.11}, {'symbol': 'ALV', 'q_bid': 5.0, 'px_bid': 126.72, 'px_ask': 126.81, 'q_ask': 4.0, 'v': 11035.0, 'q_op': 186.0, 'c': 126.75, 'pct_change': 0.65}, {'symbol': 'AMRN', 'q_bid': 100.0, 'px_bid': 15.19, 'px_ask': 15.48, 'q_ask': 300.0, 'v': 2161.0, 'q_op': 23.0, 'c': 15.34, 'pct_change': -0.23}, {'symbol': 'AMX', 'q_bid': 1960.0, 'px_bid': 21.27, 'px_ask': 21.28, 'q_ask': 517.0, 'v': 53154.0, 'q_op': 272.0, 'c': 21.285, 'pct_change': 3.58}, {'symbol': 'ARBK', 'q_bid': 500.0, 'px_bid': 0.273, 'px_ask': 0.279, 'q_ask': 100.0, 'v': 10107.0, 'q_op': 12.0, 'c': 0.279, 'pct_change': 0.5}, {'symbol': 'ASR', 'q_bid': 100.0, 'px_bid': 343.6, 'px_ask': 344.04, 'q_ask': 19.0, 'v': 4508.0, 'q_op': 302.0, 'c': 343.85, 'pct_change': 0.53}, {'symbol': 'ASX', 'q_bid': 6684.0, 'px_bid': 11.68, 'px_ask': 11.69, 'q_ask': 13510.0, 'v': 56778.0, 'q_op': 127.0, 'c': 11.685, 'pct_change': -0.21}, {'symbol': 'ATAI', 'q_bid': 404.0, 'px_bid': 5.59, 'px_ask': 5.61, 'q_ask': 300.0, 'v': 31222.0, 'q_op': 574.0, 'c': 5.59, 'pct_change': 14.55}, {'symbol': 'AU', 'q_bid': 134.0, 'px_bid': 69.46, 'px_ask': 69.52, 'q_ask': 100.0, 'v': 25970.0, 'q_op': 1421.0, 'c': 69.48, 'pct_change': 0.16}, {'symbol': 'AZ', 'q_bid': 100.0, 'px_bid': 8.37, 'px_ask': 8.64, 'q_ask': 100.0, 'v': 20156.0, 'q_op': 86.0, 'c': 8.57, 'pct_change': -2.72}, {'symbol': 'AZN', 'q_bid': 314.0, 'px_bid': 75.96, 'px_ask': 75.99, 'q_ask': 218.0, 'v': 19977.0, 'q_op': 1009.0, 'c': 75.97, 'pct_change': -1.97}, {'symbol': 'BAB', 'q_bid': 100.0, 'px_bid': 27.18, 'px_ask': 27.21, 'q_ask': 200.0, 'v': 2374.0, 'q_op': 9.0, 'c': 27.19, 'pct_change': 0.52}, {'symbol': 'BAP', 'q_bid': 5.0, 'px_bid': 265.74, 'px_ask': 266.32, 'q_ask': 22.0, 'v': 7530.0, 'q_op': 153.0, 'c': 265.945, 'pct_change': -0.31}, {'symbol': 'BB', 'q_bid': 6000.0, 'px_bid': 4.26, 'px_ask': 4.27, 'q_ask': 5705.0, 'v': 56818.0, 'q_op': 134.0, 'c': 4.265, 'pct_change': -3.07}, {'symbol': 'BBAR', 'q_bid': 100.0, 'px_bid': 10.07, 'px_ask': 10.14, 'q_ask': 3.0, 'v': 11498.0, 'q_op': 307.0, 'c': 10.1, 'pct_change': 2.54}, {'symbol': 'BBD', 'q_bid': 56004.0, 'px_bid': 3.39, 'px_ask': 3.4, 'q_ask': 49376.0, 'v': 27629.0, 'q_op': 102.0, 'c': 3.395, 'pct_change': 2.26}, {'symbol': 'BCE', 'q_bid': 3075.0, 'px_bid': 23.25, 'px_ask': 23.26, 'q_ask': 1812.0, 'v': 59037.0, 'q_op': 324.0, 'c': 23.255, 'pct_change': 0.8}, {'symbol': 'BCH', 'q_bid': 8.0, 'px_bid': 30.57, 'px_ask': 30.69, 'q_ask': 200.0, 'v': 27053.0, 'q_op': 104.0, 'c': 30.625, 'pct_change': 3.01}, {'symbol': 'BCS', 'q_bid': 4088.0, 'px_bid': 20.96, 'px_ask': 20.97, 'q_ask': 2500.0, 'v': 13734.0, 'q_op': 181.0, 'c': 20.955, 'pct_change': 0.12}, {'symbol': 'BGY', 'q_bid': 400.0, 'px_bid': 5.74, 'px_ask': 5.75, 'q_ask': 350.0, 'v': 2102.0, 'q_op': 6.0, 'c': 5.74, 'pct_change': -0.35}, {'symbol': 'BHP', 'q_bid': 100.0, 'px_bid': 53.27, 'px_ask': 53.29, 'q_ask': 610.0, 'v': 6769.0, 'q_op': 311.0, 'c': 53.275, 'pct_change': 0.24}, {'symbol': 'BILI', 'q_bid': 200.0, 'px_bid': 25.77, 'px_ask': 25.78, 'q_ask': 517.0, 'v': 60836.0, 'q_op': 394.0, 'c': 25.775, 'pct_change': -4.0}, {'symbol': 'BIP', 'q_bid': 72.0, 'px_bid': 31.47, 'px_ask': 31.57, 'q_ask': 100.0, 'v': 31900.0, 'q_op': 141.0, 'c': 31.47, 'pct_change': 0.8}, {'symbol': 'BLX', 'q_bid': 65.0, 'px_bid': 47.41, 'px_ask': 47.54, 'q_ask': 100.0, 'v': 1937.0, 'q_op': 34.0, 'c': 47.43, 'pct_change': 1.04}, {'symbol': 'BMA', 'q_bid': 2.0, 'px_bid': 47.82, 'px_ask': 48.32, 'q_ask': 200.0, 'v': 9202.0, 'q_op': 403.0, 'c': 47.82, 'pct_change': 1.29}, {'symbol': 'BMO', 'q_bid': 100.0, 'px_bid': 130.59, 'px_ask': 130.63, 'q_ask': 105.0, 'v': 36815.0, 'q_op': 432.0, 'c': 130.6, 'pct_change': 0.76}, {'symbol': 'BN', 'q_bid': 37.0, 'px_bid': 71.61, 'px_ask' ...

# %%
# Assuming data is a list of dictionaries
for item in data:
    print(item)
# Out:
# {'symbol': 'AEM', 'q_bid': 5.0, 'px_bid': 162.42, 'px_ask': 162.46, 'q_ask': 100.0, 'v': 51739.0, 'q_op': 1528.0, 'c': 162.44, 'pct_change': 0.78}
# {'symbol': 'AER', 'q_bid': 197.0, 'px_bid': 122.21, 'px_ask': 122.24, 'q_ask': 200.0, 'v': 26894.0, 'q_op': 234.0, 'c': 122.23, 'pct_change': -0.11}
# {'symbol': 'ALV', 'q_bid': 5.0, 'px_bid': 126.72, 'px_ask': 126.81, 'q_ask': 4.0, 'v': 11035.0, 'q_op': 186.0, 'c': 126.75, 'pct_change': 0.65}
# {'symbol': 'AMRN', 'q_bid': 100.0, 'px_bid': 15.19, 'px_ask': 15.48, 'q_ask': 300.0, 'v': 2161.0, 'q_op': 23.0, 'c': 15.34, 'pct_change': -0.23}
# {'symbol': 'AMX', 'q_bid': 1960.0, 'px_bid': 21.27, 'px_ask': 21.28, 'q_ask': 517.0, 'v': 53154.0, 'q_op': 272.0, 'c': 21.285, 'pct_change': 3.58}
# {'symbol': 'ARBK', 'q_bid': 500.0, 'px_bid': 0.273, 'px_ask': 0.279, 'q_ask': 100.0, 'v': 10107.0, 'q_op': 12.0, 'c': 0.279, 'pct_change': 0.5}
# {'symbol': 'ASR', 'q_bid': 100.0, 'px_bid': 343.6, 'px_ask': 344.04, 'q_ask': 19.0, 'v': 4508.0, 'q_op': 302.0, 'c': 343.85, 'pct_change': 0.53}
# {'symbol': 'ASX', 'q_bid': 6684.0, 'px_bid': 11.68, 'px_ask': 11.69, 'q_ask': 13510.0, 'v': 56778.0, 'q_op': 127.0, 'c': 11.685, 'pct_change': -0.21}
# {'symbol': 'ATAI', 'q_bid': 404.0, 'px_bid': 5.59, 'px_ask': 5.61, 'q_ask': 300.0, 'v': 31222.0, 'q_op': 574.0, 'c': 5.59, 'pct_change': 14.55}
# {'symbol': 'AU', 'q_bid': 134.0, 'px_bid': 69.46, 'px_ask': 69.52, 'q_ask': 100.0, 'v': 25970.0, 'q_op': 1421.0, 'c': 69.48, 'pct_change': 0.16}
# {'symbol': 'AZ', 'q_bid': 100.0, 'px_bid': 8.37, 'px_ask': 8.64, 'q_ask': 100.0, 'v': 20156.0, 'q_op': 86.0, 'c': 8.57, 'pct_change': -2.72}
# {'symbol': 'AZN', 'q_bid': 314.0, 'px_bid': 75.96, 'px_ask': 75.99, 'q_ask': 218.0, 'v': 19977.0, 'q_op': 1009.0, 'c': 75.97, 'pct_change': -1.97}
# {'symbol': 'BAB', 'q_bid': 100.0, 'px_bid': 27.18, 'px_ask': 27.21, 'q_ask': 200.0, 'v': 2374.0, 'q_op': 9.0, 'c': 27.19, 'pct_change': 0.52}
# {'symbol': 'BAP', 'q_bid': 5.0, 'px_bid': 265.74, 'px_ask': 266.32, 'q_ask': 22.0, 'v': 7530.0, 'q_op': 153.0, 'c': 265.945, 'pct_change': -0.31}
# {'symbol': 'BB', 'q_bid': 6000.0, 'px_bid': 4.26, 'px_ask': 4.27, 'q_ask': 5705.0, 'v': 56818.0, 'q_op': 134.0, 'c': 4.265, 'pct_change': -3.07}
# {'symbol': 'BBAR', 'q_bid': 100.0, 'px_bid': 10.07, 'px_ask': 10.14, 'q_ask': 3.0, 'v': 11498.0, 'q_op': 307.0, 'c': 10.1, 'pct_change': 2.54}
# {'symbol': 'BBD', 'q_bid': 56004.0, 'px_bid': 3.39, 'px_ask': 3.4, 'q_ask': 49376.0, 'v': 27629.0, 'q_op': 102.0, 'c': 3.395, 'pct_change': 2.26}
# {'symbol': 'BCE', 'q_bid': 3075.0, 'px_bid': 23.25, 'px_ask': 23.26, 'q_ask': 1812.0, 'v': 59037.0, 'q_op': 324.0, 'c': 23.255, 'pct_change': 0.8}
# {'symbol': 'BCH', 'q_bid': 8.0, 'px_bid': 30.57, 'px_ask': 30.69, 'q_ask': 200.0, 'v': 27053.0, 'q_op': 104.0, 'c': 30.625, 'pct_change': 3.01}
# {'symbol': 'BCS', 'q_bid': 4088.0, 'px_bid': 20.96, 'px_ask': 20.97, 'q_ask': 2500.0, 'v': 13734.0, 'q_op': 181.0, 'c': 20.955, 'pct_change': 0.12}
# {'symbol': 'BGY', 'q_bid': 400.0, 'px_bid': 5.74, 'px_ask': 5.75, 'q_ask': 350.0, 'v': 2102.0, 'q_op': 6.0, 'c': 5.74, 'pct_change': -0.35}
# {'symbol': 'BHP', 'q_bid': 100.0, 'px_bid': 53.27, 'px_ask': 53.29, 'q_ask': 610.0, 'v': 6769.0, 'q_op': 311.0, 'c': 53.275, 'pct_change': 0.24}
# {'symbol': 'BILI', 'q_bid': 200.0, 'px_bid': 25.77, 'px_ask': 25.78, 'q_ask': 517.0, 'v': 60836.0, 'q_op': 394.0, 'c': 25.775, 'pct_change': -4.0}
# {'symbol': 'BIP', 'q_bid': 72.0, 'px_bid': 31.47, 'px_ask': 31.57, 'q_ask': 100.0, 'v': 31900.0, 'q_op': 141.0, 'c': 31.47, 'pct_change': 0.8}
# {'symbol': 'BLX', 'q_bid': 65.0, 'px_bid': 47.41, 'px_ask': 47.54, 'q_ask': 100.0, 'v': 1937.0, 'q_op': 34.0, 'c': 47.43, 'pct_change': 1.04}
# {'symbol': 'BMA', 'q_bid': 2.0, 'px_bid': 47.82, 'px_ask': 48.32, 'q_ask': 200.0, 'v': 9202.0, 'q_op': 403.0, 'c': 47.82, 'pct_change': 1.29}
# {'symbol': 'BMO', 'q_bid': 100.0, 'px_bid': 130.59, 'px_ask': 130.63, 'q_ask': 105.0, 'v': 36815.0, 'q_op': 432.0, 'c': 130.6, 'pct_change': 0.76}
# {'symbol': 'BN', 'q_bid': 37.0, 'px_bid': 71.61, 'px_ask': 71.64, 'q_ask': 500.0, 'v': 63314.0, 'q_op': 747.0, 'c': 71.61, 'pct_change': -1.54}
# {'symbol': 'BNL', 'q_bid': 345.0, 'px_bid': 18.3, 'px_ask': 18.32, 'q_ask': 300.0, 'v': 24358.0, 'q_op': 86.0, 'c': 18.31, 'pct_change': 0.16}
# {'symbol': 'BNS', 'q_bid': 1864.0, 'px_bid': 64.39, 'px_ask': 64.4, 'q_ask': 400.0, 'v': 36641.0, 'q_op': 785.0, 'c': 64.4, 'pct_change': -0.06}
# {'symbol': 'BOX', 'q_bid': 128.0, 'px_bid': 32.38, 'px_ask': 32.41, 'q_ask': 16.0, 'v': 1338.0, 'q_op': 364.0, 'c': 32.39, 'pct_change': -0.06}
# {'symbol': 'BP', 'q_bid': 700.0, 'px_bid': 34.72, 'px_ask': 34.73, 'q_ask': 2300.0, 'v': 5688.0, 'q_op': 688.0, 'c': 34.725, 'pct_change': 1.03}
# {'symbol': 'BSY', 'q_bid': 100.0, 'px_bid': 52.5, 'px_ask': 52.58, 'q_ask': 10.0, 'v': 41002.0, 'q_op': 291.0, 'c': 52.54, 'pct_change': -1.83}
# {'symbol': 'BTI', 'q_bid': 114.0, 'px_bid': 53.15, 'px_ask': 53.16, 'q_ask': 1324.0, 'v': 11507.0, 'q_op': 1194.0, 'c': 53.16, 'pct_change': -1.32}
# {'symbol': 'BUD', 'q_bid': 417.0, 'px_bid': 59.0, 'px_ask': 59.01, 'q_ask': 10.0, 'v': 64084.0, 'q_op': 209.0, 'c': 58.99, 'pct_change': 0.68}
# {'symbol': 'CAE', 'q_bid': 100.0, 'px_bid': 28.6, 'px_ask': 28.61, 'q_ask': 600.0, 'v': 6172.0, 'q_op': 284.0, 'c': 28.61, 'pct_change': 2.36}
# {'symbol': 'CANG', 'q_bid': 498.0, 'px_bid': 4.39, 'px_ask': 4.44, 'q_ask': 100.0, 'v': 3453.0, 'q_op': 42.0, 'c': 4.42, 'pct_change': -3.49}
# {'symbol': 'CCJ', 'q_bid': 100.0, 'px_bid': 86.88, 'px_ask': 86.89, 'q_ask': 185.0, 'v': 35495.0, 'q_op': 2128.0, 'c': 86.89, 'pct_change': 0.67}
# {'symbol': 'CCU', 'q_bid': 190.0, 'px_bid': 11.88, 'px_ask': 12.04, 'q_ask': 100.0, 'v': 1955.0, 'q_op': 33.0, 'c': 11.91, 'pct_change': 0.93}
# {'symbol': 'CEPU', 'q_bid': 2.0, 'px_bid': 8.82, 'px_ask': 8.92, 'q_ask': 200.0, 'v': 40443.0, 'q_op': 156.0, 'c': 8.83, 'pct_change': 1.85}
# {'symbol': 'CGV', 'q_bid': 700.0, 'px_bid': 14.83, 'px_ask': 14.92, 'q_ask': 700.0, 'v': 900.0, 'q_op': 2.0, 'c': 14.89, 'pct_change': 0.34}
# {'symbol': 'CHA', 'q_bid': 100.0, 'px_bid': 16.85, 'px_ask': 17.79, 'q_ask': 100.0, 'v': 14476.0, 'q_op': 71.0, 'c': 16.835, 'pct_change': -2.41}
# {'symbol': 'CIB', 'q_bid': 200.0, 'px_bid': 52.41, 'px_ask': 52.61, 'q_ask': 69.0, 'v': 11155.0, 'q_op': 89.0, 'c': 52.63, 'pct_change': 0.23}
# {'symbol': 'CIG', 'q_bid': 12300.0, 'px_bid': 2.13, 'px_ask': 2.14, 'q_ask': 12834.0, 'v': 53574.0, 'q_op': 25.0, 'c': 2.135, 'pct_change': 3.14}
# {'symbol': 'CLS', 'q_bid': 100.0, 'px_bid': 257.56, 'px_ask': 257.78, 'q_ask': 100.0, 'v': 4871.0, 'q_op': 1253.0, 'c': 257.755, 'pct_change': 1.16}
# {'symbol': 'CM', 'q_bid': 100.0, 'px_bid': 81.71, 'px_ask': 81.72, 'q_ask': 90.0, 'v': 54454.0, 'q_op': 581.0, 'c': 81.72, 'pct_change': 0.59}
# {'symbol': 'CNH', 'q_bid': 10887.0, 'px_bid': 10.94, 'px_ask': 10.95, 'q_ask': 3000.0, 'v': 1613.0, 'q_op': 228.0, 'c': 10.945, 'pct_change': -0.5}
# {'symbol': 'CNI', 'q_bid': 5.0, 'px_bid': 92.09, 'px_ask': 92.1, 'q_ask': 100.0, 'v': 49797.0, 'q_op': 373.0, 'c': 92.08, 'pct_change': 0.08}
# {'symbol': 'CNQ', 'q_bid': 3576.0, 'px_bid': 32.11, 'px_ask': 32.12, 'q_ask': 2535.0, 'v': 57010.0, 'q_op': 1048.0, 'c': 32.11, 'pct_change': 0.0}
# {'symbol': 'CP', 'q_bid': 105.0, 'px_bid': 74.08, 'px_ask': 74.1, 'q_ask': 27.0, 'v': 60573.0, 'q_op': 579.0, 'c': 74.095, 'pct_change': -0.72}
# {'symbol': 'CPA', 'q_bid': 4.0, 'px_bid': 122.2, 'px_ask': 122.6, 'q_ask': 3.0, 'v': 12887.0, 'q_op': 144.0, 'c': 122.44, 'pct_change': 2.07}
# {'symbol': 'CRESY', 'q_bid': 100.0, 'px_bid': 9.26, 'px_ask': 9.47, 'q_ask': 4.0, 'v': 10006.0, 'q_op': 70.0, 'c': 9.41, 'pct_change': -1.36}
# {'symbol': 'CRH', 'q_bid': 10.0, 'px_bid': 114.0, 'px_ask': 114.42, 'q_ask': 100.0, 'v': 36261.0, 'q_op': 1289.0, 'c': 114.03, 'pct_change': -0.6}
# {'symbol': 'CSAN', 'q_bid': 354.0, 'px_bid': 4.76, 'px_ask': 4.77, 'q_ask': 2200.0, 'v': 47284.0, 'q_op': 89.0, 'c': 4.765, 'pct_change': 2.47}
# {'symbol': 'CSR', 'q_bid': 6.0, 'px_bid': 58.64, 'px_ask': 58.89, 'q_ask': 100.0, 'v': 2756.0, 'q_op': 48.0, 'c': 58.72, 'pct_change': 0.41}
# {'symbol': 'CUK', 'q_bid': 420.0, 'px_bid': 27.91, 'px_ask': 27.92, 'q_ask': 974.0, 'v': 54876.0, 'q_op': 230.0, 'c': 27.915, 'pct_change': 0.02}
# {'symbol': 'CX', 'q_bid': 16484.0, 'px_bid': 9.14, 'px_ask': 9.15, 'q_ask': 3907.0, 'v': 56700.0, 'q_op': 205.0, 'c': 9.145, 'pct_change': -0.81}
# {'symbol': 'CYD', 'q_bid': 100.0, 'px_bid': 40.83, 'px_ask': 41.01, 'q_ask': 2.0, 'v': 14583.0, 'q_op': 75.0, 'c': 40.97, 'pct_change': 1.34}
# {'symbol': 'DAC', 'q_bid': 42.0, 'px_bid': 92.87, 'px_ask': 93.66, 'q_ask': 100.0, 'v': 812.0, 'q_op': 37.0, 'c': 92.88, 'pct_change': 0.17}
# {'symbol': 'DAVA', 'q_bid': 7.0, 'px_bid': 9.16, 'px_ask': 9.16, 'q_ask': 100.0, 'v': 34761.0, 'q_op': 110.0, 'c': 9.165, 'pct_change': 0.16}
# {'symbol': 'DB', 'q_bid': 636.0, 'px_bid': 36.25, 'px_ask': 36.26, 'q_ask': 300.0, 'v': 64921.0, 'q_op': 242.0, 'c': 36.26, 'pct_change': -0.47}
# {'symbol': 'DEO', 'q_bid': 100.0, 'px_bid': 96.07, 'px_ask': 96.33, 'q_ask': 100.0, 'v': 35546.0, 'q_op': 280.0, 'c': 96.32, 'pct_change': 0.35}
# {'symbol': 'DNN', 'q_bid': 38600.0, 'px_bid': 2.83, 'px_ask': 2.84, 'q_ask': 49484.0, 'v': 19121.0, 'q_op': 257.0, 'c': 2.83, 'pct_change': 1.8}
# {'symbol': 'DT', 'q_bid': 9.0, 'px_bid': 47.76, 'px_ask': 47.77, 'q_ask': 2.0, 'v': 3798.0, 'q_op': 442.0, 'c': 47.77, 'pct_change': -1.71}
# {'symbol': 'E', 'q_bid': 50.0, 'px_bid': 34.96, 'px_ask': 35.08, 'q_ask': 200.0, 'v': 7669.0, 'q_op': 92.0, 'c': 34.97, 'pct_change': 1.52}
# {'symbol': 'EC', 'q_bid': 1100.0, 'px_bid': 9.4, 'px_ask': 9.41, 'q_ask': 1557.0, 'v': 20553.0, 'q_op': 79.0, 'c': 9.405, 'pct_change': 4.38}
# {'symbol': 'EDN', 'q_bid': 100.0, 'px_bid': 18.73, 'px_ask': 19.03, 'q_ask': 100.0, 'v': 15598.0, 'q_op': 151.0, 'c': 18.74, 'pct_change': 2.91}
# {'symbol': 'EDU', 'q_bid': 100.0, 'px_bid': 50.86, 'px_ask': 50.98, 'q_ask': 200.0, 'v': 17731.0, 'q_op': 150.0, 'c': 50.83, 'pct_change': -3.71}
# {'symbol': 'EGO', 'q_bid': 599.0, 'px_bid': 28.61, 'px_ask': 28.62, 'q_ask': 100.0, 'v': 17798.0, 'q_op': 412.0, 'c': 28.625, 'pct_change': 0.44}
# {'symbol': 'ELP', 'q_bid': 300.0, 'px_bid': 9.89, 'px_ask': 9.9, 'q_ask': 122.0, 'v': 12874.0, 'q_op': 36.0, 'c': 9.89, 'pct_change': 2.06}
# {'symbol': 'ENB', 'q_bid': 2186.0, 'px_bid': 49.57, 'px_ask': 49.58, 'q_ask': 700.0, 'v': 3102.0, 'q_op': 431.0, 'c': 49.575, 'pct_change': 0.78}
# {'symbol': 'EPC', 'q_bid': 6.0, 'px_bid': 19.51, 'px_ask': 19.54, 'q_ask': 11.0, 'v': 16527.0, 'q_op': 147.0, 'c': 19.52, 'pct_change': -2.16}
# {'symbol': 'ERJ', 'q_bid': 3.0, 'px_bid': 60.65, 'px_ask': 60.82, 'q_ask': 200.0, 'v': 61102.0, 'q_op': 301.0, 'c': 60.615, 'pct_change': 0.57}
# {'symbol': 'ESEA', 'q_bid': 100.0, 'px_bid': 59.62, 'px_ask': 65.76, 'q_ask': 100.0, 'v': 2084.0, 'q_op': 42.0, 'c': 62.33, 'pct_change': -4.2}
# {'symbol': 'EXK', 'q_bid': 14990.0, 'px_bid': 7.67, 'px_ask': 7.68, 'q_ask': 200.0, 'v': 11069.0, 'q_op': 570.0, 'c': 7.675, 'pct_change': -1.85}
# {'symbol': 'FLY', 'q_bid': 22.0, 'px_bid': 41.63, 'px_ask': 41.87, 'q_ask': 95.0, 'v': 3873.0, 'q_op': 433.0, 'c': 41.63, 'pct_change': -15.93}
# {'symbol': 'FMS', 'q_bid': 100.0, 'px_bid': 25.61, 'px_ask': 25.68, 'q_ask': 15.0, 'v': 5338.0, 'q_op': 33.0, 'c': 25.67, 'pct_change': 0.12}
# {'symbol': 'FMX', 'q_bid': 110.0, 'px_bid': 98.24, 'px_ask': 98.35, 'q_ask': 100.0, 'v': 23843.0, 'q_op': 178.0, 'c': 98.28, 'pct_change': 1.32}
# {'symbol': 'FRSX', 'q_bid': 100.0, 'px_bid': 2.2, 'px_ask': 2.43, 'q_ask': 100.0, 'v': 100.0, 'q_op': 1.0, 'c': 2.26, 'pct_change': 0.89}
# {'symbol': 'GFI', 'q_bid': 17.0, 'px_bid': 41.82, 'px_ask': 41.83, 'q_ask': 62.0, 'v': 65008.0, 'q_op': 1309.0, 'c': 41.82, 'pct_change': -1.13}
# {'symbol': 'GGAL', 'q_bid': 108.0, 'px_bid': 31.51, 'px_ask': 31.52, 'q_ask': 1.0, 'v': 1203.0, 'q_op': 911.0, 'c': 31.51, 'pct_change': -1.62}
# {'symbol': 'GGB', 'q_bid': 32701.0, 'px_bid': 3.15, 'px_ask': 3.16, 'q_ask': 39058.0, 'v': 8844.0, 'q_op': 55.0, 'c': 3.15, 'pct_change': 1.61}
# {'symbol': 'GIB', 'q_bid': 100.0, 'px_bid': 90.8, 'px_ask': 90.9, 'q_ask': 100.0, 'v': 13518.0, 'q_op': 146.0, 'c': 90.84, 'pct_change': -2.83}
# {'symbol': 'GIL', 'q_bid': 100.0, 'px_bid': 57.42, 'px_ask': 57.45, 'q_ask': 200.0, 'v': 6166.0, 'q_op': 454.0, 'c': 57.43, 'pct_change': 1.97}
# {'symbol': 'GILT', 'q_bid': 600.0, 'px_bid': 11.93, 'px_ask': 12.06, 'q_ask': 700.0, 'v': 60234.0, 'q_op': 159.0, 'c': 12.0, 'pct_change': 1.35}
# {'symbol': 'GRVY', 'q_bid': 100.0, 'px_bid': 63.25, 'px_ask': 68.25, 'q_ask': 100.0, 'v': 421.0, 'q_op': 5.0, 'c': 63.5, 'pct_change': -0.39}
# {'symbol': 'GSK', 'q_bid': 2066.0, 'px_bid': 40.51, 'px_ask': 40.52, 'q_ask': 100.0, 'v': 36564.0, 'q_op': 587.0, 'c': 40.52, 'pct_change': -0.95}
# {'symbol': 'HIMX', 'q_bid': 100.0, 'px_bid': 8.69, 'px_ask': 8.7, 'q_ask': 646.0, 'v': 3115.0, 'q_op': 169.0, 'c': 8.695, 'pct_change': -1.86}
# {'symbol': 'HKD', 'q_bid': 100.0, 'px_bid': 1.91, 'px_ask': 1.95, 'q_ask': 200.0, 'v': 1330.0, 'q_op': 17.0, 'c': 1.92, 'pct_change': -0.52}
# {'symbol': 'HMC', 'q_bid': 307.0, 'px_bid': 33.88, 'px_ask': 33.89, 'q_ask': 895.0, 'v': 27662.0, 'q_op': 102.0, 'c': 33.88, 'pct_change': 0.3}
# {'symbol': 'HMY', 'q_bid': 1279.0, 'px_bid': 18.08, 'px_ask': 18.09, 'q_ask': 518.0, 'v': 7149.0, 'q_op': 1095.0, 'c': 18.085, 'pct_change': 2.7}
# {'symbol': 'HSBC', 'q_bid': 10.0, 'px_bid': 70.16, 'px_ask': 70.18, 'q_ask': 320.0, 'v': 16774.0, 'q_op': 305.0, 'c': 70.2, 'pct_change': 0.31}
# {'symbol': 'HUYA', 'q_bid': 1100.0, 'px_bid': 3.33, 'px_ask': 3.34, 'q_ask': 1800.0, 'v': 20323.0, 'q_op': 32.0, 'c': 3.34, 'pct_change': -1.76}
# {'symbol': 'IAG', 'q_bid': 2700.0, 'px_bid': 11.99, 'px_ask': 12.01, 'q_ask': 4233.0, 'v': 3645.0, 'q_op': 591.0, 'c': 12.005, 'pct_change': 0.29}
# {'symbol': 'ICLR', 'q_bid': 5.0, 'px_bid': 170.16, 'px_ask': 170.97, 'q_ask': 105.0, 'v': 18875.0, 'q_op': 310.0, 'c': 170.29, 'pct_change': -0.3}
# {'symbol': 'IHG', 'q_bid': 7.0, 'px_bid': 118.68, 'px_ask': 118.84, 'q_ask': 6.0, 'v': 4816.0, 'q_op': 91.0, 'c': 118.74, 'pct_change': 0.4}
# {'symbol': 'IMAB', 'q_bid': 100.0, 'px_bid': 3.62, 'px_ask': 3.85, 'q_ask': 500.0, 'v': 11404.0, 'q_op': 28.0, 'c': 3.825, 'pct_change': -1.42}
# {'symbol': 'ING', 'q_bid': 937.0, 'px_bid': 25.71, 'px_ask': 25.72, 'q_ask': 1116.0, 'v': 53817.0, 'q_op': 102.0, 'c': 25.71, 'pct_change': 1.1}
# {'symbol': 'INSG', 'q_bid': 100.0, 'px_bid': 13.79, 'px_ask': 13.84, 'q_ask': 110.0, 'v': 15906.0, 'q_op': 93.0, 'c': 13.82, 'pct_change': 3.06}
# {'symbol': 'IRS', 'q_bid': 100.0, 'px_bid': 12.6, 'px_ask': 12.71, 'q_ask': 9.0, 'v': 14625.0, 'q_op': 83.0, 'c': 12.64, 'pct_change': -2.39}
# {'symbol': 'ITP', 'q_bid': 100.0, 'px_bid': 0.262, 'px_ask': 0.345, 'q_ask': 100.0, 'v': 50711.0, 'q_op': 62.0, 'c': 0.305, 'pct_change': 27.08}
# {'symbol': 'ITRN', 'q_bid': 100.0, 'px_bid': 35.16, 'px_ask': 35.57, 'q_ask': 100.0, 'v': 3407.0, 'q_op': 55.0, 'c': 35.435, 'pct_change': -0.49}
# {'symbol': 'ITUB', 'q_bid': 36984.0, 'px_bid': 7.41, 'px_ask': 7.42, 'q_ask': 5844.0, 'v': 31206.0, 'q_op': 135.0, 'c': 7.415, 'pct_change': 2.42}
# {'symbol': 'IX', 'q_bid': 100.0, 'px_bid': 26.55, 'px_ask': 26.95, 'q_ask': 100.0, 'v': 982.0, 'q_op': 25.0, 'c': 26.92, 'pct_change': -0.26}
# {'symbol': 'JFIN', 'q_bid': 100.0, 'px_bid': 11.01, 'px_ask': 11.31, 'q_ask': 100.0, 'v': 1016.0, 'q_op': 16.0, 'c': 11.1, 'pct_change': 1.28}
# {'symbol': 'JHX', 'q_bid': 22.0, 'px_bid': 19.32, 'px_ask': 19.34, 'q_ask': 3508.0, 'v': 28407.0, 'q_op': 326.0, 'c': 19.335, 'pct_change': -1.25}
# {'symbol': 'JMIA', 'q_bid': 164.0, 'px_bid': 11.33, 'px_ask': 11.34, 'q_ask': 205.0, 'v': 5506.0, 'q_op': 237.0, 'c': 11.335, 'pct_change': -4.35}
# {'symbol': 'KB', 'q_bid': 10.0, 'px_bid': 82.44, 'px_ask': 82.84, 'q_ask': 100.0, 'v': 9151.0, 'q_op': 100.0, 'c': 82.47, 'pct_change': -2.17}
# {'symbol': 'KEP', 'q_bid': 100.0, 'px_bid': 13.3, 'px_ask': 13.48, 'q_ask': 100.0, 'v': 7631.0, 'q_op': 36.0, 'c': 13.405, 'pct_change': 1.25}
# {'symbol': 'KFS', 'q_bid': 75.0, 'px_bid': 14.37, 'px_ask': 14.42, 'q_ask': 100.0, 'v': 520.0, 'q_op': 7.0, 'c': 14.4, 'pct_change': 0.56}
# {'symbol': 'KGC', 'q_bid': 7323.0, 'px_bid': 24.47, 'px_ask': 24.48, 'q_ask': 1400.0, 'v': 81.0, 'q_op': 1169.0, 'c': 24.48, 'pct_change': 1.03}
# {'symbol': 'KOF', 'q_bid': 6.0, 'px_bid': 85.54, 'px_ask': 85.65, 'q_ask': 100.0, 'v': 10751.0, 'q_op': 96.0, 'c': 85.64, 'pct_change': 0.95}
# {'symbol': 'LOGI', 'q_bid': 6.0, 'px_bid': 111.29, 'px_ask': 111.56, 'q_ask': 38.0, 'v': 12283.0, 'q_op': 161.0, 'c': 111.38, 'pct_change': -1.5}
# {'symbol': 'LOMA', 'q_bid': 200.0, 'px_bid': 7.86, 'px_ask': 7.87, 'q_ask': 253.0, 'v': 46399.0, 'q_op': 183.0, 'c': 7.86, 'pct_change': -3.32}
# {'symbol': 'LPL', 'q_bid': 233.0, 'px_bid': 4.89, 'px_ask': 4.93, 'q_ask': 100.0, 'v': 18557.0, 'q_op': 43.0, 'c': 4.925, 'pct_change': -0.51}
# {'symbol': 'LYG', 'q_bid': 12767.0, 'px_bid': 4.46, 'px_ask': 4.47, 'q_ask': 25540.0, 'v': 27083.0, 'q_op': 68.0, 'c': 4.465, 'pct_change': -0.11}
# {'symbol': 'MATV', 'q_bid': 122.0, 'px_bid': 11.74, 'px_ask': 11.82, 'q_ask': 600.0, 'v': 19150.0, 'q_op': 96.0, 'c': 11.74, 'pct_change': -3.69}
# {'symbol': 'MC', 'q_bid': 105.0, 'px_bid': 75.09, 'px_ask': 75.16, 'q_ask': 26.0, 'v': 13837.0, 'q_op': 250.0, 'c': 75.13, 'pct_change': -0.9}
# {'symbol': 'MFC', 'q_bid': 700.0, 'px_bid': 31.07, 'px_ask': 31.09, 'q_ask': 1450.0, 'v': 29981.0, 'q_op': 329.0, 'c': 31.08, 'pct_change': -2.05}
# {'symbol': 'MFG', 'q_bid': 7395.0, 'px_bid': 6.74, 'px_ask': 6.75, 'q_ask': 5916.0, 'v': 2987.0, 'q_op': 32.0, 'c': 6.745, 'pct_change': -0.07}
# {'symbol': 'MGA', 'q_bid': 100.0, 'px_bid': 46.21, 'px_ask': 46.23, 'q_ask': 100.0, 'v': 30433.0, 'q_op': 333.0, 'c': 46.215, 'pct_change': -0.42}
# {'symbol': 'MT', 'q_bid': 100.0, 'px_bid': 35.96, 'px_ask': 36.0, 'q_ask': 17.0, 'v': 30341.0, 'q_op': 130.0, 'c': 35.97, 'pct_change': 0.45}
# {'symbol': 'MTA', 'q_bid': 100.0, 'px_bid': 5.98, 'px_ask': 6.06, 'q_ask': 100.0, 'v': 14074.0, 'q_op': 65.0, 'c': 5.99, 'pct_change': 1.87}
# {'symbol': 'NAK', 'q_bid': 10.0, 'px_bid': 0.935, 'px_ask': 0.95, 'q_ask': 2500.0, 'v': 60950.0, 'q_op': 144.0, 'c': 0.94, 'pct_change': 1.62}
# {'symbol': 'NG', 'q_bid': 8066.0, 'px_bid': 7.73, 'px_ask': 7.74, 'q_ask': 3200.0, 'v': 1205.0, 'q_op': 315.0, 'c': 7.73, 'pct_change': 1.18}
# {'symbol': 'NGG', 'q_bid': 25.0, 'px_bid': 71.32, 'px_ask': 71.45, 'q_ask': 100.0, 'v': 20004.0, 'q_op': 372.0, 'c': 71.32, 'pct_change': 0.51}
# {'symbol': 'NICE', 'q_bid': 100.0, 'px_bid': 148.27, 'px_ask': 149.06, 'q_ask': 2.0, 'v': 22078.0, 'q_op': 169.0, 'c': 149.03, 'pct_change': 0.7}
# {'symbol': 'NMM', 'q_bid': 100.0, 'px_bid': 45.17, 'px_ask': 50.55, 'q_ask': 100.0, 'v': 4387.0, 'q_op': 23.0, 'c': 48.29, 'pct_change': 2.03}
# {'symbol': 'NMR', 'q_bid': 349.0, 'px_bid': 7.45, 'px_ask': 7.46, 'q_ask': 552.0, 'v': 11048.0, 'q_op': 27.0, 'c': 7.45, 'pct_change': -0.53}
# {'symbol': 'NNDM', 'q_bid': 1892.0, 'px_bid': 1.56, 'px_ask': 1.57, 'q_ask': 1617.0, 'v': 42677.0, 'q_op': 83.0, 'c': 1.565, 'pct_change': 6.46}
# {'symbol': 'NOA', 'q_bid': 100.0, 'px_bid': 13.58, 'px_ask': 13.6, 'q_ask': 100.0, 'v': 4453.0, 'q_op': 36.0, 'c': 13.61, 'pct_change': -0.95}
# {'symbol': 'NOK', 'q_bid': 45333.0, 'px_bid': 4.85, 'px_ask': 4.86, 'q_ask': 15744.0, 'v': 15144.0, 'q_op': 244.0, 'c': 4.85, 'pct_change': 1.68}
# {'symbol': 'NVO', 'q_bid': 100.0, 'px_bid': 59.56, 'px_ask': 59.57, 'q_ask': 29.0, 'v': 58270.0, 'q_op': 1012.0, 'c': 59.57, 'pct_change': -1.88}
# {'symbol': 'NVS', 'q_bid': 100.0, 'px_bid': 122.5, 'px_ask': 122.8, 'q_ask': 10.0, 'v': 27203.0, 'q_op': 660.0, 'c': 122.8, 'pct_change': -0.45}
# {'symbol': 'OMAB', 'q_bid': 100.0, 'px_bid': 108.09, 'px_ask': 108.69, 'q_ask': 100.0, 'v': 986.0, 'q_op': 51.0, 'c': 108.52, 'pct_change': 1.43}
# {'symbol': 'PAC', 'q_bid': 13.0, 'px_bid': 254.7, 'px_ask': 255.16, 'q_ask': 19.0, 'v': 2310.0, 'q_op': 117.0, 'c': 254.88, 'pct_change': -0.19}
# {'symbol': 'PAM', 'q_bid': 100.0, 'px_bid': 64.55, 'px_ask': 65.58, 'q_ask': 100.0, 'v': 20460.0, 'q_op': 161.0, 'c': 64.71, 'pct_change': 1.57}
# {'symbol': 'PBR', 'q_bid': 11869.0, 'px_bid': 13.16, 'px_ask': 13.17, 'q_ask': 30717.0, 'v': 62365.0, 'q_op': 409.0, 'c': 13.165, 'pct_change': 3.5}
# {'symbol': 'PDS', 'q_bid': 100.0, 'px_bid': 58.23, 'px_ask': 58.29, 'q_ask': 100.0, 'v': 6572.0, 'q_op': 79.0, 'c': 58.24, 'pct_change': 0.85}
# {'symbol': 'PHG', 'q_bid': 67.0, 'px_bid': 27.77, 'px_ask': 27.79, 'q_ask': 166.0, 'v': 20498.0, 'q_op': 72.0, 'c': 27.78, 'pct_change': -0.96}
# {'symbol': 'PHI', 'q_bid': 25.0, 'px_bid': 19.3, 'px_ask': 19.73, 'q_ask': 100.0, 'v': 2216.0, 'q_op': 26.0, 'c': 19.71, 'pct_change': 1.55}
# {'symbol': 'PKX', 'q_bid': 100.0, 'px_bid': 49.35, 'px_ask': 49.8, 'q_ask': 100.0, 'v': 3269.0, 'q_op': 62.0, 'c': 49.57, 'pct_change': -1.53}
# {'symbol': 'PPBT', 'q_bid': 100.0, 'px_bid': 0.575, 'px_ask': 0.655, 'q_ask': 100.0, 'v': 4205.0, 'q_op': 8.0, 'c': 0.58, 'pct_change': 2.24}
# {'symbol': 'PRTH', 'q_bid': 1.0, 'px_bid': 7.28, 'px_ask': 7.32, 'q_ask': 400.0, 'v': 7861.0, 'q_op': 55.0, 'c': 7.28, 'pct_change': -2.54}
# {'symbol': 'PSO', 'q_bid': 600.0, 'px_bid': 13.83, 'px_ask': 13.84, 'q_ask': 85.0, 'v': 19426.0, 'q_op': 39.0, 'c': 13.83, 'pct_change': -1.85}
# {'symbol': 'PUK', 'q_bid': 1754.0, 'px_bid': 27.59, 'px_ask': 27.6, 'q_ask': 700.0, 'v': 30601.0, 'q_op': 87.0, 'c': 27.58, 'pct_change': -0.9}
# {'symbol': 'QD', 'q_bid': 55.0, 'px_bid': 4.16, 'px_ask': 4.19, 'q_ask': 107.0, 'v': 7833.0, 'q_op': 39.0, 'c': 4.165, 'pct_change': 3.61}
# {'symbol': 'QGEN', 'q_bid': 113.0, 'px_bid': 45.59, 'px_ask': 45.61, 'q_ask': 115.0, 'v': 11191.0, 'q_op': 165.0, 'c': 45.605, 'pct_change': -0.27}
# {'symbol': 'RC', 'q_bid': 1583.0, 'px_bid': 4.19, 'px_ask': 4.2, 'q_ask': 1000.0, 'v': 47181.0, 'q_op': 67.0, 'c': 4.195, 'pct_change': 0.12}
# {'symbol': 'RCI', 'q_bid': 949.0, 'px_bid': 35.31, 'px_ask': 35.32, 'q_ask': 100.0, 'v': 39414.0, 'q_op': 206.0, 'c': 35.315, 'pct_change': 0.76}
# {'symbol': 'RCON', 'q_bid': 100.0, 'px_bid': 1.9, 'px_ask': 2.13, 'q_ask': 100.0, 'v': 420.0, 'q_op': 1.0, 'c': 2.06, 'pct_change': 5.1}
# {'symbol': 'RDY', 'q_bid': 220.0, 'px_bid': 14.47, 'px_ask': 14.48, 'q_ask': 800.0, 'v': 29424.0, 'q_op': 55.0, 'c': 14.48, 'pct_change': -0.82}
# {'symbol': 'RIO', 'q_bid': 10.0, 'px_bid': 63.55, 'px_ask': 63.56, 'q_ask': 215.0, 'v': 45467.0, 'q_op': 591.0, 'c': 63.555, 'pct_change': -0.15}
# {'symbol': 'RY', 'q_bid': 100.0, 'px_bid': 148.11, 'px_ask': 148.23, 'q_ask': 100.0, 'v': 43990.0, 'q_op': 628.0, 'c': 148.1, 'pct_change': -0.34}
# {'symbol': 'RYAAY', 'q_bid': 125.0, 'px_bid': 56.76, 'px_ask': 56.83, 'q_ask': 34.0, 'v': 3485.0, 'q_op': 348.0, 'c': 56.72, 'pct_change': 2.77}
# {'symbol': 'SAN', 'q_bid': 3.0, 'px_bid': 10.24, 'px_ask': 10.25, 'q_ask': 9310.0, 'v': 9995.0, 'q_op': 242.0, 'c': 10.245, 'pct_change': 1.04}
# {'symbol': 'SAP', 'q_bid': 100.0, 'px_bid': 264.78, 'px_ask': 265.47, 'q_ask': 1.0, 'v': 35752.0, 'q_op': 597.0, 'c': 265.37, 'pct_change': 0.0}
# {'symbol': 'SB', 'q_bid': 200.0, 'px_bid': 4.56, 'px_ask': 4.58, 'q_ask': 100.0, 'v': 3611.0, 'q_op': 25.0, 'c': 4.57, 'pct_change': 2.01}
# {'symbol': 'SBLK', 'q_bid': 100.0, 'px_bid': 19.79, 'px_ask': 19.81, 'q_ask': 260.0, 'v': 39403.0, 'q_op': 144.0, 'c': 19.8, 'pct_change': 3.45}
# {'symbol': 'SBS', 'q_bid': 853.0, 'px_bid': 24.98, 'px_ask': 25.0, 'q_ask': 300.0, 'v': 21323.0, 'q_op': 121.0, 'c': 24.98, 'pct_change': 3.35}
# {'symbol': 'SCM', 'q_bid': 100.0, 'px_bid': 13.74, 'px_ask': 14.71, 'q_ask': 100.0, 'v': 8881.0, 'q_op': 22.0, 'c': 13.785, 'pct_change': -0.83}
# {'symbol': 'SHG', 'q_bid': 19.0, 'px_bid': 49.62, 'px_ask': 49.68, 'q_ask': 4.0, 'v': 3889.0, 'q_op': 70.0, 'c': 49.67, 'pct_change': -0.48}
# {'symbol': 'SID', 'q_bid': 12500.0, 'px_bid': 1.5, 'px_ask': 1.52, 'q_ask': 27800.0, 'v': 31916.0, 'q_op': 21.0, 'c': 1.51, 'pct_change': 0.0}
# {'symbol': 'SIFY', 'q_bid': 13.0, 'px_bid': 11.83, 'px_ask': 12.57, 'q_ask': 100.0, 'v': 1007.0, 'q_op': 7.0, 'c': 11.91, 'pct_change': -3.13}
# {'symbol': 'SIMO', 'q_bid': 25.0, 'px_bid': 91.36, 'px_ask': 91.61, 'q_ask': 2.0, 'v': 27403.0, 'q_op': 229.0, 'c': 91.48, 'pct_change': -3.77}
# {'symbol': 'SKM', 'q_bid': 57.0, 'px_bid': 21.84, 'px_ask': 21.87, 'q_ask': 100.0, 'v': 4880.0, 'q_op': 35.0, 'c': 21.875, 'pct_change': -0.34}
# {'symbol': 'SLF', 'q_bid': 100.0, 'px_bid': 59.69, 'px_ask': 59.73, 'q_ask': 200.0, 'v': 10725.0, 'q_op': 200.0, 'c': 59.7, 'pct_change': -0.37}
# {'symbol': 'SMFG', 'q_bid': 976.0, 'px_bid': 16.96, 'px_ask': 16.97, 'q_ask': 5600.0, 'v': 8254.0, 'q_op': 76.0, 'c': 16.965, 'pct_change': -0.85}
# {'symbol': 'SNN', 'q_bid': 100.0, 'px_bid': 36.12, 'px_ask': 36.13, 'q_ask': 100.0, 'v': 44050.0, 'q_op': 172.0, 'c': 36.115, 'pct_change': -1.11}
# {'symbol': 'SNY', 'q_bid': 487.0, 'px_bid': 46.86, 'px_ask': 46.88, 'q_ask': 100.0, 'v': 7500.0, 'q_op': 646.0, 'c': 46.87, 'pct_change': -0.3}
# {'symbol': 'SOL', 'q_bid': 100.0, 'px_bid': 1.87, 'px_ask': 1.88, 'q_ask': 999.0, 'v': 3480.0, 'q_op': 2.0, 'c': 1.875, 'pct_change': -0.27}
# {'symbol': 'SONY', 'q_bid': 2605.0, 'px_bid': 29.77, 'px_ask': 29.78, 'q_ask': 5238.0, 'v': 15121.0, 'q_op': 409.0, 'c': 29.775, 'pct_change': 0.15}
# {'symbol': 'SPNS', 'q_bid': 104.0, 'px_bid': 42.92, 'px_ask': 42.93, 'q_ask': 200.0, 'v': 16720.0, 'q_op': 51.0, 'c': 42.93, 'pct_change': -0.16}
# {'symbol': 'SQM', 'q_bid': 300.0, 'px_bid': 43.09, 'px_ask': 43.26, 'q_ask': 100.0, 'v': 36494.0, 'q_op': 236.0, 'c': 43.23, 'pct_change': -0.14}
# {'symbol': 'SSL', 'q_bid': 700.0, 'px_bid': 6.12, 'px_ask': 6.13, 'q_ask': 1748.0, 'v': 46491.0, 'q_op': 84.0, 'c': 6.12, 'pct_change': -1.77}
# {'symbol': 'STM', 'q_bid': 1360.0, 'px_bid': 28.65, 'px_ask': 28.66, 'q_ask': 400.0, 'v': 32287.0, 'q_op': 417.0, 'c': 28.655, 'pct_change': 0.79}
# {'symbol': 'STN', 'q_bid': 100.0, 'px_bid': 107.04, 'px_ask': 107.11, 'q_ask': 100.0, 'v': 11375.0, 'q_op': 179.0, 'c': 107.05, 'pct_change': -4.41}
# {'symbol': 'SU', 'q_bid': 300.0, 'px_bid': 42.26, 'px_ask': 42.27, 'q_ask': 161.0, 'v': 21576.0, 'q_op': 864.0, 'c': 42.27, 'pct_change': 1.17}
# {'symbol': 'SUPV', 'q_bid': 27.0, 'px_bid': 6.1, 'px_ask': 6.11, 'q_ask': 100.0, 'v': 62452.0, 'q_op': 273.0, 'c': 6.1, 'pct_change': -1.93}
# {'symbol': 'SUZ', 'q_bid': 1200.0, 'px_bid': 9.49, 'px_ask': 9.51, 'q_ask': 968.0, 'v': 64261.0, 'q_op': 77.0, 'c': 9.505, 'pct_change': 0.8}
# {'symbol': 'TAC', 'q_bid': 100.0, 'px_bid': 13.6, 'px_ask': 13.62, 'q_ask': 100.0, 'v': 27501.0, 'q_op': 110.0, 'c': 13.62, 'pct_change': -1.73}
# {'symbol': 'TD', 'q_bid': 437.0, 'px_bid': 78.73, 'px_ask': 78.75, 'q_ask': 400.0, 'v': 33433.0, 'q_op': 716.0, 'c': 78.73, 'pct_change': -0.69}
# {'symbol': 'TEF', 'q_bid': 209.0, 'px_bid': 5.12, 'px_ask': 5.13, 'q_ask': 1302.0, 'v': 21961.0, 'q_op': 29.0, 'c': 5.12, 'pct_change': -1.35}
# {'symbol': 'TEO', 'q_bid': 200.0, 'px_bid': 7.32, 'px_ask': 7.4, 'q_ask': 200.0, 'v': 20466.0, 'q_op': 75.0, 'c': 7.38, 'pct_change': -0.67}
# {'symbol': 'TEVA', 'q_bid': 6408.0, 'px_bid': 19.46, 'px_ask': 19.47, 'q_ask': 400.0, 'v': 20682.0, 'q_op': 785.0, 'c': 19.465, 'pct_change': 3.15}
# {'symbol': 'TGB', 'q_bid': 4900.0, 'px_bid': 3.72, 'px_ask': 3.73, 'q_ask': 7498.0, 'v': 61254.0, 'q_op': 94.0, 'c': 3.73, 'pct_change': -1.58}
# {'symbol': 'TGS', 'q_bid': 4.0, 'px_bid': 22.49, 'px_ask': 22.63, 'q_ask': 600.0, 'v': 41440.0, 'q_op': 204.0, 'c': 22.51, 'pct_change': -0.62}
# {'symbol': 'TKC', 'q_bid': 4661.0, 'px_bid': 6.1, 'px_ask': 6.11, 'q_ask': 2700.0, 'v': 10480.0, 'q_op': 36.0, 'c': 6.105, 'pct_change': 0.41}
# {'symbol': 'TLK', 'q_bid': 100.0, 'px_bid': 19.44, 'px_ask': 19.45, 'q_ask': 500.0, 'v': 13399.0, 'q_op': 67.0, 'c': 19.445, 'pct_change': 0.13}
# {'symbol': 'TM', 'q_bid': 102.0, 'px_bid': 200.68, 'px_ask': 200.83, 'q_ask': 100.0, 'v': 8164.0, 'q_op': 284.0, 'c': 200.73, 'pct_change': 0.02}
# {'symbol': 'TNK', 'q_bid': 2.0, 'px_bid': 54.39, 'px_ask': 54.43, 'q_ask': 3.0, 'v': 9609.0, 'q_op': 136.0, 'c': 54.41, 'pct_change': 2.39}
# {'symbol': 'TRI', 'q_bid': 100.0, 'px_bid': 160.35, 'px_ask': 160.82, 'q_ask': 5.0, 'v': 53615.0, 'q_op': 570.0, 'c': 160.75, 'pct_change': -1.43}
# {'symbol': 'TRP', 'q_bid': 100.0, 'px_bid': 53.26, 'px_ask': 53.28, 'q_ask': 100.0, 'v': 56003.0, 'q_op': 303.0, 'c': 53.27, 'pct_change': 0.74}
# {'symbol': 'TS', 'q_bid': 275.0, 'px_bid': 35.22, 'px_ask': 35.24, 'q_ask': 300.0, 'v': 10017.0, 'q_op': 360.0, 'c': 35.23, 'pct_change': 1.32}
# {'symbol': 'TSM', 'q_bid': 216.0, 'px_bid': 282.77, 'px_ask': 282.81, 'q_ask': 119.0, 'v': 63453.0, 'q_op': 8158.0, 'c': 282.79, 'pct_change': 3.73}
# {'symbol': 'TTE', 'q_bid': 100.0, 'px_bid': 61.52, 'px_ask': 61.53, 'q_ask': 100.0, 'v': 46168.0, 'q_op': 378.0, 'c': 61.525, 'pct_change': 1.24}
# {'symbol': 'TU', 'q_bid': 31700.0, 'px_bid': 15.82, 'px_ask': 15.83, 'q_ask': 12470.0, 'v': 10515.0, 'q_op': 211.0, 'c': 15.825, 'pct_change': 0.03}
# {'symbol': 'TV', 'q_bid': 1802.0, 'px_bid': 2.78, 'px_ask': 2.79, 'q_ask': 1538.0, 'v': 43651.0, 'q_op': 39.0, 'c': 2.785, 'pct_change': 0.54}
# {'symbol': 'TX', 'q_bid': 200.0, 'px_bid': 33.97, 'px_ask': 34.16, 'q_ask': 100.0, 'v': 6006.0, 'q_op': 75.0, 'c': 34.24, 'pct_change': 0.32}
# {'symbol': 'UBS', 'q_bid': 83.0, 'px_bid': 42.08, 'px_ask': 42.1, 'q_ask': 201.0, 'v': 61563.0, 'q_op': 210.0, 'c': 42.08, 'pct_change': -0.71}
# {'symbol': 'UL', 'q_bid': 473.0, 'px_bid': 60.55, 'px_ask': 60.56, 'q_ask': 200.0, 'v': 14920.0, 'q_op': 498.0, 'c': 60.56, 'pct_change': 0.12}
# {'symbol': 'UMC', 'q_bid': 4857.0, 'px_bid': 7.36, 'px_ask': 7.37, 'q_ask': 20741.0, 'v': 28184.0, 'q_op': 65.0, 'c': 7.37, 'pct_change': 1.52}
# {'symbol': 'VALE', 'q_bid': 62883.0, 'px_bid': 10.93, 'px_ask': 10.94, 'q_ask': 21677.0, 'v': 61743.0, 'q_op': 183.0, 'c': 10.935, 'pct_change': 0.69}
# {'symbol': 'WBD', 'q_bid': 489.0, 'px_bid': 19.52, 'px_ask': 19.54, 'q_ask': 1200.0, 'v': 33690.0, 'q_op': 1736.0, 'c': 19.52, 'pct_change': -0.46}
# {'symbol': 'WF', 'q_bid': 1.0, 'px_bid': 56.56, 'px_ask': 60.9, 'q_ask': 100.0, 'v': 291.0, 'q_op': 8.0, 'c': 57.39, 'pct_change': 0.24}
# {'symbol': 'WH', 'q_bid': 13.0, 'px_bid': 82.59, 'px_ask': 82.7, 'q_ask': 100.0, 'v': 25631.0, 'q_op': 279.0, 'c': 82.6, 'pct_change': 0.81}
# {'symbol': 'WIT', 'q_bid': 20407.0, 'px_bid': 2.72, 'px_ask': 2.73, 'q_ask': 15160.0, 'v': 17417.0, 'q_op': 33.0, 'c': 2.725, 'pct_change': -2.33}
# {'symbol': 'WNS', 'q_bid': 100.0, 'px_bid': 76.01, 'px_ask': 76.02, 'q_ask': 1630.0, 'v': 60580.0, 'q_op': 111.0, 'c': 76.015, 'pct_change': -0.23}
# {'symbol': 'YPF', 'q_bid': 100.0, 'px_bid': 27.43, 'px_ask': 27.47, 'q_ask': 8.0, 'v': 44207.0, 'q_op': 599.0, 'c': 27.44, 'pct_change': 1.93}
# {'symbol': 'YRD', 'q_bid': 100.0, 'px_bid': 5.9, 'px_ask': 6.02, 'q_ask': 100.0, 'v': 2891.0, 'q_op': 4.0, 'c': 5.91, 'pct_change': -2.31}
# {'symbol': 'YSG', 'q_bid': 100.0, 'px_bid': 9.21, 'px_ask': 9.27, 'q_ask': 5.0, 'v': 6605.0, 'q_op': 30.0, 'c': 9.24, 'pct_change': -6.29}
# {'symbol': 'ZLAB', 'q_bid': 100.0, 'px_bid': 32.01, 'px_ask': 32.08, 'q_ask': 100.0, 'v': 6135.0, 'q_op': 97.0, 'c': 32.075, 'pct_change': -3.24}

# %%
ts_price = None
for item in data:
    if item.get('symbol') == 'TS':
        ts_price = item.get('c')
        break

if ts_price is not None:
    print(f"The latest price for TS is: {ts_price}")
else:
    print("TS not found in the data.")
# Out:
# The latest price for TS is: 35.23

# %%
new_X = np.array([62.15, 96.96, 6757]).reshape(1, -1)

# %%
y_pred_new = modelo.predict(new_X)
print(f"Predicted TS value: {y_pred_new[0]:.4f}")
# Out:
# Predicted TS value: 34.2007
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
if ts_price < y_pred_new:
    print("Comprar")
else:
    print("Vender")
# Out:
# Vender
